# %% [markdown]
# # Statistical and Visualization Functions: Thicket Tutorial
#
# Thicket is a python-based toolkit for Exploratory Data Analysis (EDA) of parallel performance data that enables performance optimization and understanding of applications’ performance on supercomputers. It bridges the performance tool gap between being able to consider only a single instance of a simulation run (e.g., single platform, single measurement tool, or single scale) and finding actionable insights in multi-dimensional, multi-scale, multi-architecture, and multi-tool performance datasets.
#
# #### NOTE: An interactive version of this notebook is available in the Binder environment.
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/llnl/thicket-tutorial/develop)
#
# ***
#
# ## 1. Import Necessary Packages
#
# To explore the structure and various capabilities of thicket components, we begin by importing necessary packages.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from IPython.display import display
from IPython.display import HTML
import hatchet as ht

import thicket as th

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 2. Read in Performance Profiles
#
# For this notebook, we select profiles generated on Lawrence Livermore National Lab (LLNL) machine, lassen. We create two thicket objects, one generated with the same problem size of 1048576 and the other generated with different problem sizes (1048576 and 4194304).

# %%
clang = "../data/quartz/Clang_900_BaseSeq_O3_08388608/"
gcc = "../data/quartz/GCC_831_BaseSeq_O3_08388608/"

# create thickets for each dataset originating from clang and gcc compilers
clang_th = th.Thicket.from_caliperreader(clang)
gcc_th = th.Thicket.from_caliperreader(gcc)

# %% [markdown]
# ## 3. More Information on a Function
#
# You can use the `help()` method within Python to see the information for a given object. You can do this by typing `help(object)`.
# This will allow you to see the arguments for the function, and what will be returned. An example is below.

# %%
help(th.median)
# Out:
# Help on function median in module thicket.stats.median:
#
# median(thicket, columns=None)
#     Calculate the median for each node in the performance data table.
#
#     Designed to take in a thicket, and append one or more columns to the
#     aggregated statistics table for the median calculation for each node.
#
#     Arguments:
#         thicket (thicket): Thicket object
#         columns (list): List of hardware/timing metrics to perform median calculation
#             on. Note, if using a columnar joined thicket a list of tuples must be passed
#             in with the format (column index, column name).

# %% [markdown]
# ## 4. Creating a Combined Thicket
#
# To demonstrate the functions on both a thicket and a combined thicket, we create a combined thicket.

# %%
combined_th = th.Thicket.columnar_join([clang_th,gcc_th],['Clang','GCC'])
combined_th.dataframe.head(5)
# Out:
#                                                  Clang               \
#                                                    nid         time
# node                                     profile
# {'name': 'Base_Seq', 'type': 'function'} 0         1.0  1816.892754
#                                          1         1.0  1795.491419
#                                          2         1.0  1807.504658
#                                          3         1.0  1815.576481
#                                          4         1.0  1797.588696
#
#                                                                          \
#                                                  time (exc) ProblemSize
# node                                     profile
# {'name': 'Base_Seq', 'type': 'function'} 0         0.007212   8388608.0
#                                          1         0.007088   8388608.0
#                                          2         0.007204   8388608.0
#                                          3         0.007184   8388608.0
#                                          4         0.007045   8388608.0
#
#                                                                         \
#                                                    Reps Iterations/Rep
# node                                     profile
# {'name': 'Base_Seq', 'type': 'function'} 0        500.0      8388608.0
#                                          1        500.0      8388608.0
#                                          2        500.0      8388608.0
#                                          3        500.0      8388608.0
#                                          4        500.0      8388608.0
#
#                                                                            \
#                                                     Bytes/Rep Kernels/Rep
# node                                     profile
# {'name': 'Base_Seq', 'type': 'function'} 0        201326592.0         1.0
#                                          1        201326592.0         1.0
#                                          2        201326592.0         1.0
#                                          3        201326592.0         1.0
#                                          4        201326592.0         1.0
#
#                                                               \
#                                                    Flops/Rep
# node                                     profile
# {'name': 'Base_Seq', 'type': 'function'} 0        16777216.0
#                                          1        16777216.0
#                                          2        16777216.0
#                                          3        16777216.0
#                                          4        16777216.0
#
#                                                                     \
#                                                  Branch mispredict
# node                                     profile
# {'name': 'Base_Seq', 'type': 'function'} 0                0.979491
#                                          1                0.966137
#                                          2                0.968343
#                                          3                0.979570
#                                          4                0.983137
#
#                                                                  \
#                                                  Machine clears
# node                                     profile
# {'name': 'Base_Seq', 'type': 'function'} 0             0.020509
#                                          1             0.033863
#                                          2             0.031657
#                                          3             0.020430
#                                          4             0.016863
#
#                                                                    \
#                                                  Frontend latency
# node                                     profile
# {'name': 'Base_Seq', 'type': 'function'} 0               0.337277
#                                          1               0.246603
#                                          2               0.635900
#                                          3               0.299522
#                                          4               0.407419
#
#                                                                      \
#                                                  Frontend bandwidth
# node                                     profile
# {'name': 'Base_Seq', 'type': 'function'} 0                 0.662723
#                                          1                 0.753397
#                                          2                 0.364100
#                                          3                 0.700478
#                                          4                 0.592581
#
#                                                                           \
#                                                  Memory bound Core bound
# node                                     profile
# {'name': 'Base_Seq', 'type': 'function'} 0           0.479179   0.135116
#                                          1           0.340004   0.480677
#                                          2           0.535118   0.505700
#                                          3           0.282717   0.463486
#                                          4           0.379187   0.356157
#
#                                                                             \
#                                                  External Memory  L1 bound
# node                                     profile
# {'name': 'Base_Seq', 'type': 'function'} 0              0.057817  0.078872
#                                          1              0.059050 -0.104797
#                                          2              0.081133  0.050643
#                                          3              0.050380 -0.020838
#                                          4              0.048471  0.083823
#
#                                                                       \
#                                                   L2 bound  L3 bound
# node                                     profile
# {'name': 'Base_Seq', 'type': 'function'} 0       -0.029453  0.025042
#                                          1        0.020943  0.010510
#                                          2       -0.098516  0.015062
#                                          3       -0.055259  0.006151
#                                          4       -0.054290  0.010358
#
#                                                                            \
#                                                   Retiring Frontend bound
# node                                     profile
# {'name': 'Base_Seq', 'type': 'function'} 0        0.283309       0.524702
#                                          1        0.151999       0.364938
#                                          2        0.419837       0.703930
#                                          3        0.156757       0.269152
#                                          4        0.178366       0.548494
#
#                                                                 \
#                                                  Backend bound
# node                                     profile
# {'name': 'Base_Seq', 'type': 'function'} 0            0.224746
#                                          1            0.432142
#                                          2            0.000000
#                                          3            0.512101
#                                          4            0.261175
#
#                                                                   GCC  \
#                                                  Bad speculation  nid
# node                                     profile
# {'name': 'Base_Seq', 'type': 'function'} 0              0.000000  1.0
#                                          1              0.050920  1.0
#                                          2              0.068883  1.0
#                                          3              0.061990  1.0
#                                          4              0.011965  1.0
#
#                                                                           \
#                                                          time time (exc)
# node                                     profile
# {'name': 'Base_Seq', 'type': 'function'} 0        1819.263126   0.006786
#                                          1        1815.025167   0.006930
#                                          2        1817.831788   0.007016
#                                          3        1809.748427   0.006869
#                                          4        1810.714631   0.006808
#
#                                                                      \
#                                                  ProblemSize   Reps
# node                                     profile
# {'name': 'Base_Seq', 'type': 'function'} 0         8388608.0  500.0
#                                          1         8388608.0  500.0
#                                          2         8388608.0  500.0
#                                          3         8388608.0  500.0
#                                          4         8388608.0  500.0
#
#                                                                               \
#                                                  Iterations/Rep    Bytes/Rep
# node                                     profile
# {'name': 'Base_Seq', 'type': 'function'} 0            8388608.0  201326592.0
#                                          1            8388608.0  201326592.0
#                                          2            8388608.0  201326592.0
#                                          3            8388608.0  201326592.0
#                                          4            8388608.0  201326592.0
#
#                                                                           \
#                                                  Kernels/Rep   Flops/Rep
# node                                     profile
# {'name': 'Base_Seq', 'type': 'function'} 0               1.0  16777216.0
#                                          1               1.0  16777216.0
#                                          2               1.0  16777216.0
#                                          3               1.0  16777216.0
#                                          4               1.0  16777216.0
#
#                                                                     \
#                                                  Branch mispredict
# node                                     profile
# {'name': 'Base_Seq', 'type': 'function'} 0                0.974907
#                                          1                0.973584
#                                          2                0.978050
#                                          3                0.973691
#                                          4                0.966899
#
#                                                                            \
#                                                  Machine clears  Retiring
# node                                     profile
# {'name': 'Base_Seq', 'type': 'function'} 0             0.025093  0.147913
#                                          1             0.026416  0.133949
#                                          2             0.021950  0.153022
#                                          3             0.026309  0.125379
#                                          4             0.033101  0.182825
#
#                                                                                \
#                                                  Frontend bound Backend bound
# node                                     profile
# {'name': 'Base_Seq', 'type': 'function'} 0             0.326308      0.481055
#                                          1             0.544286      0.292846
#                                          2             0.537300      0.275903
#                                          3             0.405801      0.461832
#                                          4             0.569800      0.191780
#
#                                                                   \
#                                                  Bad speculation
# node                                     profile
# {'name': 'Base_Seq', 'type': 'function'} 0              0.044724
#                                          1              0.028919
#                                          2              0.033775
#                                          3              0.006988
#                                          4              0.055595
#
#                                                                    \
#                                                  Frontend latency
# node                                     profile
# {'name': 'Base_Seq', 'type': 'function'} 0               0.241504
#                                          1               0.470574
#                                          2               0.455921
#                                          3               0.257495
#                                          4               0.540990
#
#                                                                      \
#                                                  Frontend bandwidth
# node                                     profile
# {'name': 'Base_Seq', 'type': 'function'} 0                 0.758496
#                                          1                 0.529426
#                                          2                 0.544079
#                                          3                 0.742505
#                                          4                 0.459010
#
#                                                                           \
#                                                  Memory bound Core bound
# node                                     profile
# {'name': 'Base_Seq', 'type': 'function'} 0           0.295568   0.492738
#                                          1           0.440375   0.302979
#                                          2           0.491536   0.347057
#                                          3           0.356348   0.481020
#                                          4           0.378505   0.413123
#
#                                                                             \
#                                                  External Memory  L1 bound
# node                                     profile
# {'name': 'Base_Seq', 'type': 'function'} 0              0.052029 -0.040326
#                                          1              0.060758  0.020334
#                                          2              0.081223  0.049478
#                                          3              0.051371 -0.029927
#                                          4              0.048652 -0.018178
#
#                                                                           name
#                                                   L2 bound  L3 bound
# node                                     profile
# {'name': 'Base_Seq', 'type': 'function'} 0       -0.036910  0.008598  Base_Seq
#                                          1       -0.016642  0.011380  Base_Seq
#                                          2       -0.144951  0.018449  Base_Seq
#                                          3        0.014794  0.011881  Base_Seq
#                                          4        0.051825  0.004293  Base_Seq

# %% [markdown]
# **NOTE**
# - Single indexed statistical functions append columns to the right.
# - Columnar joined thickets are ordered in alphabetical order by column index and also by the columns underneath a column index.

# %% [markdown]
# ## 5. Aggregated Statistic Functions

# %% [markdown]
# ###  5.1 Maximum
# The `maximum` function will determine the maximum value for each node in the performance data table. In other terms, the maximum is the highest observation for a node and its associated profiles. <br>
#
# The maximum value will be appended to the aggregated statistics table and will be denoted with `_max` at the end of column name i.e. `column_max`.

# %% [markdown]
# #### Single Index Thicket Example

# %%
# define metrics to calculate the maximum on
metrics = ["time (exc)","Machine clears"]

# %%
th.maximum(clang_th,columns=metrics)
# view the first 5 entries of the aggregated statistics table
clang_th.statsframe.dataframe.head(5)
# Out:
#                                                                         name  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                            Base_Seq
# {'name': 'Algorithm', 'type': 'function'}                          Algorithm
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}            Algorithm_MEMCPY
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...  Algorithm_MEMCPY.default
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...  Algorithm_MEMCPY.library
#
#                                                     time (exc)_max  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                  0.007418
# {'name': 'Algorithm', 'type': 'function'}                 0.000637
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}          0.000252
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...        1.343627
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...        0.756431
#
#                                                     Machine clears_max
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.044086
# {'name': 'Algorithm', 'type': 'function'}                     0.045977
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              1.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.998909
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.973024

# %% [markdown]
# #### Multi-Indexed Thicket Example
# Example demonstrates how to pass a columnar joined thicket object. When passing a columnar joined thicket object, the columns argument will now take a list of tuples. Each tuple will consist of two elements. The first element will always be the column index, and the second element will be an associated column under the column index you passed.<br>
#
#  - Example: (column_index, column_name) -> ("GCC", "Machine clears")

# %%
metrics = [("Clang","time (exc)"),("GCC","Machine clears")]

# %%
th.maximum(combined_th,columns=metrics)
combined_th.statsframe.dataframe.head(5)
# Out:
#                                                                               \
#                                                                         name
# node
# {'name': 'Base_Seq', 'type': 'function'}                            Base_Seq
# {'name': 'Algorithm', 'type': 'function'}                          Algorithm
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}            Algorithm_MEMCPY
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...  Algorithm_MEMCPY.default
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...  Algorithm_MEMCPY.library
#
#                                                             Clang  \
#                                                    time (exc)_max
# node
# {'name': 'Base_Seq', 'type': 'function'}                 0.007418
# {'name': 'Algorithm', 'type': 'function'}                0.000637
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}         0.000252
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...       1.343627
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...       0.756431
#
#                                                                   GCC
#                                                    Machine clears_max
# node
# {'name': 'Base_Seq', 'type': 'function'}                     0.034919
# {'name': 'Algorithm', 'type': 'function'}                    0.078947
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}             1.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...           0.998832
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...           0.978771

# %% [markdown]
# ### 5.2 Minimum
#
# The `minimum` function will determine the minimum value for each node in the performance data table. In other terms, the minimum is the lowest observation for a node and its associated profiles. <br>
#
# The minimum value will be appended to the aggregated statistics table and will be denoted with `_min` at the end of column name i.e. `column_min`.

# %% [markdown]
# #### Single Index Thicket Example

# %%
metrics = ["time (exc)","Machine clears"]

# %%
th.minimum(clang_th,columns=metrics)
clang_th.statsframe.dataframe.head(5)
# Out:
#                                                                         name  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                            Base_Seq
# {'name': 'Algorithm', 'type': 'function'}                          Algorithm
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}            Algorithm_MEMCPY
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...  Algorithm_MEMCPY.default
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...  Algorithm_MEMCPY.library
#
#                                                     time (exc)_max  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                  0.007418
# {'name': 'Algorithm', 'type': 'function'}                 0.000637
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}          0.000252
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...        1.343627
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...        0.756431
#
#                                                     Machine clears_max  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.044086
# {'name': 'Algorithm', 'type': 'function'}                     0.045977
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              1.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.998909
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.973024
#
#                                                     time (exc)_min  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                  0.006875
# {'name': 'Algorithm', 'type': 'function'}                 0.000564
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}          0.000215
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...        1.275210
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...        0.722036
#
#                                                     Machine clears_min
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.015849
# {'name': 'Algorithm', 'type': 'function'}                     0.004092
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              0.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.987818
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.906853

# %% [markdown]
# #### Multi-Indexed Thicket Example
# Example will show how to pass a columnar joined thicket object. When passing a columnar joined thicket object, the columns argument will now take a list of tuples. Each tuple will consist of two elements. The first element will always be the column index, and the second element will be an associated column under the column index you passed.<br>
#
#  - Example: (column_index, column_name) -> ("GCC", "Machine clears")

# %%
metrics = [("Clang","time (exc)"),("GCC","Machine clears")]

# %%
th.minimum(combined_th,columns=metrics)
combined_th.statsframe.dataframe.head(5)
# Out:
#                                                                               \
#                                                                         name
# node
# {'name': 'Base_Seq', 'type': 'function'}                            Base_Seq
# {'name': 'Algorithm', 'type': 'function'}                          Algorithm
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}            Algorithm_MEMCPY
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...  Algorithm_MEMCPY.default
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...  Algorithm_MEMCPY.library
#
#                                                             Clang  \
#                                                    time (exc)_max
# node
# {'name': 'Base_Seq', 'type': 'function'}                 0.007418
# {'name': 'Algorithm', 'type': 'function'}                0.000637
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}         0.000252
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...       1.343627
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...       0.756431
#
#                                                                    \
#                                                    time (exc)_min
# node
# {'name': 'Base_Seq', 'type': 'function'}                 0.006875
# {'name': 'Algorithm', 'type': 'function'}                0.000564
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}         0.000215
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...       1.275210
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...       0.722036
#
#                                                                   GCC  \
#                                                    Machine clears_max
# node
# {'name': 'Base_Seq', 'type': 'function'}                     0.034919
# {'name': 'Algorithm', 'type': 'function'}                    0.078947
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}             1.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...           0.998832
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...           0.978771
#
#
#                                                    Machine clears_min
# node
# {'name': 'Base_Seq', 'type': 'function'}                     0.014810
# {'name': 'Algorithm', 'type': 'function'}                    0.000000
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}             0.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...           0.993177
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...           0.905950

# %% [markdown]
# ### 5.3 Median
#
# The `median` function will determine the median for each node in the performance data table. <br>
#
# The median value will be appended to the aggregated statistics table and will be denoted with `_median` at the end of column name i.e. `column_median`.

# %% [markdown]
# #### Single Index Thicket Example

# %%
metrics = ["time (exc)","Machine clears"]

# %%
th.median(clang_th,columns=metrics)
clang_th.statsframe.dataframe.head(5)
# Out:
#                                                                         name  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                            Base_Seq
# {'name': 'Algorithm', 'type': 'function'}                          Algorithm
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}            Algorithm_MEMCPY
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...  Algorithm_MEMCPY.default
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...  Algorithm_MEMCPY.library
#
#                                                     time (exc)_max  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                  0.007418
# {'name': 'Algorithm', 'type': 'function'}                 0.000637
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}          0.000252
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...        1.343627
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...        0.756431
#
#                                                     Machine clears_max  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.044086
# {'name': 'Algorithm', 'type': 'function'}                     0.045977
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              1.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.998909
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.973024
#
#                                                     time (exc)_min  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                  0.006875
# {'name': 'Algorithm', 'type': 'function'}                 0.000564
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}          0.000215
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...        1.275210
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...        0.722036
#
#                                                     Machine clears_min  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.015849
# {'name': 'Algorithm', 'type': 'function'}                     0.004092
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              0.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.987818
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.906853
#
#                                                     time (exc)_median  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                     0.007194
# {'name': 'Algorithm', 'type': 'function'}                    0.000598
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}             0.000231
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...           1.294030
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...           0.736833
#
#                                                     Machine clears_median
# node
# {'name': 'Base_Seq', 'type': 'function'}                         0.027724
# {'name': 'Algorithm', 'type': 'function'}                        0.012778
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                      NaN
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...               0.998147
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...               0.953007

# %% [markdown]
# #### Multi-Indexed Thicket Example
#
# Example will show how to pass a columnar joined thicket object. When passing a columnar joined thicket object, the columns argument will now take a list of tuples. Each tuple will consist of two elements. The first element will always be the column index, and the second element will be an associated column under the column index you passed.<br>
#
#  - Example: (column_index, column_name) -> ("GCC", "Machine clears")

# %%
metrics = [("Clang","time (exc)"),("GCC","Machine clears")]

# %%
th.median(combined_th,columns=metrics)
combined_th.statsframe.dataframe.head(5)
# Out:
#                                                                               \
#                                                                         name
# node
# {'name': 'Base_Seq', 'type': 'function'}                            Base_Seq
# {'name': 'Algorithm', 'type': 'function'}                          Algorithm
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}            Algorithm_MEMCPY
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...  Algorithm_MEMCPY.default
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...  Algorithm_MEMCPY.library
#
#                                                             Clang  \
#                                                    time (exc)_max
# node
# {'name': 'Base_Seq', 'type': 'function'}                 0.007418
# {'name': 'Algorithm', 'type': 'function'}                0.000637
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}         0.000252
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...       1.343627
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...       0.756431
#
#                                                                       \
#                                                    time (exc)_median
# node
# {'name': 'Base_Seq', 'type': 'function'}                    0.007194
# {'name': 'Algorithm', 'type': 'function'}                   0.000598
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}            0.000231
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...          1.294030
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...          0.736833
#
#                                                                    \
#                                                    time (exc)_min
# node
# {'name': 'Base_Seq', 'type': 'function'}                 0.006875
# {'name': 'Algorithm', 'type': 'function'}                0.000564
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}         0.000215
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...       1.275210
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...       0.722036
#
#                                                                   GCC  \
#                                                    Machine clears_max
# node
# {'name': 'Base_Seq', 'type': 'function'}                     0.034919
# {'name': 'Algorithm', 'type': 'function'}                    0.078947
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}             1.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...           0.998832
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...           0.978771
#
#                                                                           \
#                                                    Machine clears_median
# node
# {'name': 'Base_Seq', 'type': 'function'}                        0.026362
# {'name': 'Algorithm', 'type': 'function'}                       0.012092
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                0.027067
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...              0.996824
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...              0.949658
#
#
#                                                    Machine clears_min
# node
# {'name': 'Base_Seq', 'type': 'function'}                     0.014810
# {'name': 'Algorithm', 'type': 'function'}                    0.000000
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}             0.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...           0.993177
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...           0.905950

# %% [markdown]
# ### 5.4 Mean
#
# The `mean` function will determine the mean for each node in the performance data table. <br>
#
# The mean value will be appended to the aggregated statistics table and will be denoted with `_mean` at the end of column name i.e. `column_mean`.

# %% [markdown]
# #### Single Index Thicket Example

# %%
metrics = ["time (exc)","Machine clears"]

# %%
th.mean(clang_th,columns=metrics)
clang_th.statsframe.dataframe.head(5)
# Out:
#                                                                         name  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                            Base_Seq
# {'name': 'Algorithm', 'type': 'function'}                          Algorithm
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}            Algorithm_MEMCPY
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...  Algorithm_MEMCPY.default
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...  Algorithm_MEMCPY.library
#
#                                                     time (exc)_max  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                  0.007418
# {'name': 'Algorithm', 'type': 'function'}                 0.000637
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}          0.000252
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...        1.343627
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...        0.756431
#
#                                                     Machine clears_max  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.044086
# {'name': 'Algorithm', 'type': 'function'}                     0.045977
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              1.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.998909
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.973024
#
#                                                     time (exc)_min  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                  0.006875
# {'name': 'Algorithm', 'type': 'function'}                 0.000564
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}          0.000215
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...        1.275210
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...        0.722036
#
#                                                     Machine clears_min  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.015849
# {'name': 'Algorithm', 'type': 'function'}                     0.004092
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              0.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.987818
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.906853
#
#                                                     time (exc)_median  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                     0.007194
# {'name': 'Algorithm', 'type': 'function'}                    0.000598
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}             0.000231
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...           1.294030
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...           0.736833
#
#                                                     Machine clears_median  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                         0.027724
# {'name': 'Algorithm', 'type': 'function'}                        0.012778
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                      NaN
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...               0.998147
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...               0.953007
#
#                                                     time (exc)_mean  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                   0.007147
# {'name': 'Algorithm', 'type': 'function'}                  0.000597
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}           0.000233
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...         1.298458
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...         0.738028
#
#                                                     Machine clears_mean
# node
# {'name': 'Base_Seq', 'type': 'function'}                       0.027126
# {'name': 'Algorithm', 'type': 'function'}                      0.017969
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}               0.230749
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...             0.996256
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...             0.948031

# %% [markdown]
# #### Multi-Indexed Thicket Example
#
# Example will show how to pass a columnar joined thicket object. When passing a columnar joined thicket object, the columns argument will now take a list of tuples. Each tuple will consist of two elements. The first element will always be the column index, and the second element will be an associated column under the column index you passed.<br>
#
#  - Example: (column_index, column_name) -> ("GCC", "Machine clears")

# %%
metrics = [("Clang","time (exc)"),("GCC","Machine clears")]

# %%
th.mean(combined_th,columns=metrics)
combined_th.statsframe.dataframe.head(5)
# Out:
#                                                                               \
#                                                                         name
# node
# {'name': 'Base_Seq', 'type': 'function'}                            Base_Seq
# {'name': 'Algorithm', 'type': 'function'}                          Algorithm
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}            Algorithm_MEMCPY
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...  Algorithm_MEMCPY.default
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...  Algorithm_MEMCPY.library
#
#                                                             Clang  \
#                                                    time (exc)_max
# node
# {'name': 'Base_Seq', 'type': 'function'}                 0.007418
# {'name': 'Algorithm', 'type': 'function'}                0.000637
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}         0.000252
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...       1.343627
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...       0.756431
#
#                                                                     \
#                                                    time (exc)_mean
# node
# {'name': 'Base_Seq', 'type': 'function'}                  0.007147
# {'name': 'Algorithm', 'type': 'function'}                 0.000597
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}          0.000233
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...        1.298458
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...        0.738028
#
#                                                                       \
#                                                    time (exc)_median
# node
# {'name': 'Base_Seq', 'type': 'function'}                    0.007194
# {'name': 'Algorithm', 'type': 'function'}                   0.000598
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}            0.000231
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...          1.294030
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...          0.736833
#
#                                                                    \
#                                                    time (exc)_min
# node
# {'name': 'Base_Seq', 'type': 'function'}                 0.006875
# {'name': 'Algorithm', 'type': 'function'}                0.000564
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}         0.000215
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...       1.275210
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...       0.722036
#
#                                                                   GCC  \
#                                                    Machine clears_max
# node
# {'name': 'Base_Seq', 'type': 'function'}                     0.034919
# {'name': 'Algorithm', 'type': 'function'}                    0.078947
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}             1.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...           0.998832
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...           0.978771
#
#                                                                         \
#                                                    Machine clears_mean
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.027250
# {'name': 'Algorithm', 'type': 'function'}                     0.019933
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              0.311366
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.996608
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.944047
#
#                                                                           \
#                                                    Machine clears_median
# node
# {'name': 'Base_Seq', 'type': 'function'}                        0.026362
# {'name': 'Algorithm', 'type': 'function'}                       0.012092
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                0.027067
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...              0.996824
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...              0.949658
#
#
#                                                    Machine clears_min
# node
# {'name': 'Base_Seq', 'type': 'function'}                     0.014810
# {'name': 'Algorithm', 'type': 'function'}                    0.000000
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}             0.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...           0.993177
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...           0.905950

# %% [markdown]
# ### 5.5 Variance
#
# The `variance` function will determine the variance for each node in the performance data table. Variance will allow a user to see the spread of tdata within a node and that nodes associated profiles. <br>
#
# The variance value will be appended to the aggregated statistics table and will be denoted with `_var` at the end of column name i.e. `column_var`.

# %% [markdown]
# #### Single Index Thicket Example

# %%
metrics = ["time (exc)","Machine clears"]

# %%
th.variance(clang_th,columns=metrics)
clang_th.statsframe.dataframe.head(5)
# Out:
#                                                                         name  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                            Base_Seq
# {'name': 'Algorithm', 'type': 'function'}                          Algorithm
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}            Algorithm_MEMCPY
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...  Algorithm_MEMCPY.default
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...  Algorithm_MEMCPY.library
#
#                                                     time (exc)_max  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                  0.007418
# {'name': 'Algorithm', 'type': 'function'}                 0.000637
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}          0.000252
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...        1.343627
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...        0.756431
#
#                                                     Machine clears_max  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.044086
# {'name': 'Algorithm', 'type': 'function'}                     0.045977
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              1.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.998909
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.973024
#
#                                                     time (exc)_min  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                  0.006875
# {'name': 'Algorithm', 'type': 'function'}                 0.000564
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}          0.000215
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...        1.275210
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...        0.722036
#
#                                                     Machine clears_min  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.015849
# {'name': 'Algorithm', 'type': 'function'}                     0.004092
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              0.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.987818
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.906853
#
#                                                     time (exc)_median  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                     0.007194
# {'name': 'Algorithm', 'type': 'function'}                    0.000598
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}             0.000231
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...           1.294030
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...           0.736833
#
#                                                     Machine clears_median  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                         0.027724
# {'name': 'Algorithm', 'type': 'function'}                        0.012778
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                      NaN
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...               0.998147
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...               0.953007
#
#                                                     time (exc)_mean  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                   0.007147
# {'name': 'Algorithm', 'type': 'function'}                  0.000597
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}           0.000233
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...         1.298458
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...         0.738028
#
#                                                     Machine clears_mean  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                       0.027126
# {'name': 'Algorithm', 'type': 'function'}                      0.017969
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}               0.230749
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...             0.996256
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...             0.948031
#
#                                                     time (exc)_var  \
# node
# {'name': 'Base_Seq', 'type': 'function'}              2.549456e-08
# {'name': 'Algorithm', 'type': 'function'}             3.652100e-10
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}      1.560100e-10
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...    3.125018e-04
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...    6.953802e-05
#
#                                                     Machine clears_var
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.000072
# {'name': 'Algorithm', 'type': 'function'}                     0.000220
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              0.169282
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.000012
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.000392

# %% [markdown]
# #### Multi-Indexed Thicket Example
# Example will show how to pass a columnar joined thicket object. When passing a columnar joined thicket object, the columns argument will now take a list of tuples. Each tuple will consist of two elements. The first element will always be the column index, and the second element will be an associated column under the column index you passed.<br>
#
#  - Example: (column_index, column_name) -> ("GCC", "Machine clears")

# %%
metrics = [("Clang","time (exc)"),("GCC","Machine clears")]

# %%
th.variance(combined_th,columns=metrics)
combined_th.statsframe.dataframe.head(5)
# Out:
#                                                                               \
#                                                                         name
# node
# {'name': 'Base_Seq', 'type': 'function'}                            Base_Seq
# {'name': 'Algorithm', 'type': 'function'}                          Algorithm
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}            Algorithm_MEMCPY
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...  Algorithm_MEMCPY.default
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...  Algorithm_MEMCPY.library
#
#                                                             Clang  \
#                                                    time (exc)_max
# node
# {'name': 'Base_Seq', 'type': 'function'}                 0.007418
# {'name': 'Algorithm', 'type': 'function'}                0.000637
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}         0.000252
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...       1.343627
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...       0.756431
#
#                                                                     \
#                                                    time (exc)_mean
# node
# {'name': 'Base_Seq', 'type': 'function'}                  0.007147
# {'name': 'Algorithm', 'type': 'function'}                 0.000597
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}          0.000233
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...        1.298458
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...        0.738028
#
#                                                                       \
#                                                    time (exc)_median
# node
# {'name': 'Base_Seq', 'type': 'function'}                    0.007194
# {'name': 'Algorithm', 'type': 'function'}                   0.000598
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}            0.000231
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...          1.294030
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...          0.736833
#
#                                                                    \
#                                                    time (exc)_min
# node
# {'name': 'Base_Seq', 'type': 'function'}                 0.006875
# {'name': 'Algorithm', 'type': 'function'}                0.000564
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}         0.000215
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...       1.275210
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...       0.722036
#
#                                                                    \
#                                                    time (exc)_var
# node
# {'name': 'Base_Seq', 'type': 'function'}             2.549456e-08
# {'name': 'Algorithm', 'type': 'function'}            3.652100e-10
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}     1.560100e-10
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...   3.125018e-04
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...   6.953802e-05
#
#                                                                   GCC  \
#                                                    Machine clears_max
# node
# {'name': 'Base_Seq', 'type': 'function'}                     0.034919
# {'name': 'Algorithm', 'type': 'function'}                    0.078947
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}             1.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...           0.998832
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...           0.978771
#
#                                                                         \
#                                                    Machine clears_mean
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.027250
# {'name': 'Algorithm', 'type': 'function'}                     0.019933
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              0.311366
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.996608
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.944047
#
#                                                                           \
#                                                    Machine clears_median
# node
# {'name': 'Base_Seq', 'type': 'function'}                        0.026362
# {'name': 'Algorithm', 'type': 'function'}                       0.012092
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                0.027067
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...              0.996824
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...              0.949658
#
#                                                                        \
#                                                    Machine clears_min
# node
# {'name': 'Base_Seq', 'type': 'function'}                     0.014810
# {'name': 'Algorithm', 'type': 'function'}                    0.000000
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}             0.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...           0.993177
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...           0.905950
#
#
#                                                    Machine clears_var
# node
# {'name': 'Base_Seq', 'type': 'function'}                     0.000035
# {'name': 'Algorithm', 'type': 'function'}                    0.000463
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}             0.203608
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...           0.000003
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...           0.000503

# %% [markdown]
# ### 5.6 Standard Deviation
#
# The `std` function will determine the standard deviation for each node in the performance data table. Standard deviation describes how dispersed the data is in relation to the mean. <br>
#
# The standard deviation value will be appended to the aggregated statistics table and will be denoted with `_std` at the end of column name i.e. `column_std`.

# %% [markdown]
# #### Single Index Thicket Example

# %%
metrics = ["time (exc)","Machine clears"]

# %%
th.std(clang_th,columns=metrics)
clang_th.statsframe.dataframe.head(5)
# Out:
#                                                                         name  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                            Base_Seq
# {'name': 'Algorithm', 'type': 'function'}                          Algorithm
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}            Algorithm_MEMCPY
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...  Algorithm_MEMCPY.default
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...  Algorithm_MEMCPY.library
#
#                                                     time (exc)_max  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                  0.007418
# {'name': 'Algorithm', 'type': 'function'}                 0.000637
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}          0.000252
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...        1.343627
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...        0.756431
#
#                                                     Machine clears_max  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.044086
# {'name': 'Algorithm', 'type': 'function'}                     0.045977
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              1.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.998909
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.973024
#
#                                                     time (exc)_min  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                  0.006875
# {'name': 'Algorithm', 'type': 'function'}                 0.000564
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}          0.000215
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...        1.275210
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...        0.722036
#
#                                                     Machine clears_min  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.015849
# {'name': 'Algorithm', 'type': 'function'}                     0.004092
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              0.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.987818
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.906853
#
#                                                     time (exc)_median  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                     0.007194
# {'name': 'Algorithm', 'type': 'function'}                    0.000598
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}             0.000231
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...           1.294030
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...           0.736833
#
#                                                     Machine clears_median  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                         0.027724
# {'name': 'Algorithm', 'type': 'function'}                        0.012778
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                      NaN
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...               0.998147
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...               0.953007
#
#                                                     time (exc)_mean  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                   0.007147
# {'name': 'Algorithm', 'type': 'function'}                  0.000597
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}           0.000233
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...         1.298458
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...         0.738028
#
#                                                     Machine clears_mean  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                       0.027126
# {'name': 'Algorithm', 'type': 'function'}                      0.017969
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}               0.230749
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...             0.996256
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...             0.948031
#
#                                                     time (exc)_var  \
# node
# {'name': 'Base_Seq', 'type': 'function'}              2.549456e-08
# {'name': 'Algorithm', 'type': 'function'}             3.652100e-10
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}      1.560100e-10
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...    3.125018e-04
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...    6.953802e-05
#
#                                                     Machine clears_var  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.000072
# {'name': 'Algorithm', 'type': 'function'}                     0.000220
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              0.169282
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.000012
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.000392
#
#                                                     time (exc)_std  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                  0.000160
# {'name': 'Algorithm', 'type': 'function'}                 0.000019
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}          0.000012
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...        0.017678
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...        0.008339
#
#                                                     Machine clears_std
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.008508
# {'name': 'Algorithm', 'type': 'function'}                     0.014843
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              0.411439
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.003459
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.019788

# %% [markdown]
# #### Multi-Indexed Thicket Example
# Example will show how to pass a columnar joined thicket object. When passing a columnar joined thicket object, the columns argument will now take a list of tuples. Each tuple will consist of two elements. The first element will always be the column index, and the second element will be an associated column under the column index you passed.<br>
#
#  - Example: (column_index, column_name) -> ("GCC", "Machine clears")

# %%
metrics = [("Clang","time (exc)"),("GCC","Machine clears")]

# %%
th.std(combined_th,columns=metrics)
combined_th.statsframe.dataframe.head(5)
# Out:
#                                                                               \
#                                                                         name
# node
# {'name': 'Base_Seq', 'type': 'function'}                            Base_Seq
# {'name': 'Algorithm', 'type': 'function'}                          Algorithm
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}            Algorithm_MEMCPY
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...  Algorithm_MEMCPY.default
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...  Algorithm_MEMCPY.library
#
#                                                             Clang  \
#                                                    time (exc)_max
# node
# {'name': 'Base_Seq', 'type': 'function'}                 0.007418
# {'name': 'Algorithm', 'type': 'function'}                0.000637
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}         0.000252
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...       1.343627
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...       0.756431
#
#                                                                     \
#                                                    time (exc)_mean
# node
# {'name': 'Base_Seq', 'type': 'function'}                  0.007147
# {'name': 'Algorithm', 'type': 'function'}                 0.000597
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}          0.000233
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...        1.298458
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...        0.738028
#
#                                                                       \
#                                                    time (exc)_median
# node
# {'name': 'Base_Seq', 'type': 'function'}                    0.007194
# {'name': 'Algorithm', 'type': 'function'}                   0.000598
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}            0.000231
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...          1.294030
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...          0.736833
#
#                                                                    \
#                                                    time (exc)_min
# node
# {'name': 'Base_Seq', 'type': 'function'}                 0.006875
# {'name': 'Algorithm', 'type': 'function'}                0.000564
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}         0.000215
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...       1.275210
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...       0.722036
#
#                                                                    \
#                                                    time (exc)_std
# node
# {'name': 'Base_Seq', 'type': 'function'}                 0.000160
# {'name': 'Algorithm', 'type': 'function'}                0.000019
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}         0.000012
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...       0.017678
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...       0.008339
#
#                                                                    \
#                                                    time (exc)_var
# node
# {'name': 'Base_Seq', 'type': 'function'}             2.549456e-08
# {'name': 'Algorithm', 'type': 'function'}            3.652100e-10
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}     1.560100e-10
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...   3.125018e-04
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...   6.953802e-05
#
#                                                                   GCC  \
#                                                    Machine clears_max
# node
# {'name': 'Base_Seq', 'type': 'function'}                     0.034919
# {'name': 'Algorithm', 'type': 'function'}                    0.078947
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}             1.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...           0.998832
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...           0.978771
#
#                                                                         \
#                                                    Machine clears_mean
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.027250
# {'name': 'Algorithm', 'type': 'function'}                     0.019933
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              0.311366
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.996608
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.944047
#
#                                                                           \
#                                                    Machine clears_median
# node
# {'name': 'Base_Seq', 'type': 'function'}                        0.026362
# {'name': 'Algorithm', 'type': 'function'}                       0.012092
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                0.027067
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...              0.996824
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...              0.949658
#
#                                                                        \
#                                                    Machine clears_min
# node
# {'name': 'Base_Seq', 'type': 'function'}                     0.014810
# {'name': 'Algorithm', 'type': 'function'}                    0.000000
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}             0.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...           0.993177
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...           0.905950
#
#                                                                        \
#                                                    Machine clears_std
# node
# {'name': 'Base_Seq', 'type': 'function'}                     0.005898
# {'name': 'Algorithm', 'type': 'function'}                    0.021524
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}             0.451230
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...           0.001797
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...           0.022419
#
#
#                                                    Machine clears_var
# node
# {'name': 'Base_Seq', 'type': 'function'}                     0.000035
# {'name': 'Algorithm', 'type': 'function'}                    0.000463
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}             0.203608
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...           0.000003
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...           0.000503

# %% [markdown]
# ### 5.7 Percentiles
#
# The `percentiles` function will determine the q-th percentiles for each node in the performance data table. <br>
#
#  - The 25th percentile is the lower quartile, and is the value at which 25% of the answers lie below that value.
#  - The 50th percentile is the median and half othe values lie below the median and half lie above the median.
#  - The 75th percentile is the upper quartiles, and is the value at which 25% of the answers lie above that value and 75% of the answer lie below that value.
#
# The calculated percentiles will be appended to the aggregated statistics table and will be denoted with `_percentiles` at the end of column name i.e. `column_percentiles`.

# %% [markdown]
# #### Single Index Thicket Example

# %%
metrics = ["time (exc)","Machine clears"]

# %%
th.percentiles(clang_th,columns=metrics)
clang_th.statsframe.dataframe.head(5)
# Out:
#                                                                         name  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                            Base_Seq
# {'name': 'Algorithm', 'type': 'function'}                          Algorithm
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}            Algorithm_MEMCPY
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...  Algorithm_MEMCPY.default
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...  Algorithm_MEMCPY.library
#
#                                                     time (exc)_max  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                  0.007418
# {'name': 'Algorithm', 'type': 'function'}                 0.000637
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}          0.000252
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...        1.343627
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...        0.756431
#
#                                                     Machine clears_max  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.044086
# {'name': 'Algorithm', 'type': 'function'}                     0.045977
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              1.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.998909
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.973024
#
#                                                     time (exc)_min  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                  0.006875
# {'name': 'Algorithm', 'type': 'function'}                 0.000564
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}          0.000215
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...        1.275210
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...        0.722036
#
#                                                     Machine clears_min  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.015849
# {'name': 'Algorithm', 'type': 'function'}                     0.004092
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              0.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.987818
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.906853
#
#                                                     time (exc)_median  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                     0.007194
# {'name': 'Algorithm', 'type': 'function'}                    0.000598
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}             0.000231
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...           1.294030
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...           0.736833
#
#                                                     Machine clears_median  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                         0.027724
# {'name': 'Algorithm', 'type': 'function'}                        0.012778
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                      NaN
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...               0.998147
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...               0.953007
#
#                                                     time (exc)_mean  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                   0.007147
# {'name': 'Algorithm', 'type': 'function'}                  0.000597
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}           0.000233
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...         1.298458
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...         0.738028
#
#                                                     Machine clears_mean  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                       0.027126
# {'name': 'Algorithm', 'type': 'function'}                      0.017969
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}               0.230749
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...             0.996256
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...             0.948031
#
#                                                     time (exc)_var  \
# node
# {'name': 'Base_Seq', 'type': 'function'}              2.549456e-08
# {'name': 'Algorithm', 'type': 'function'}             3.652100e-10
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}      1.560100e-10
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...    3.125018e-04
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...    6.953802e-05
#
#                                                     Machine clears_var  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.000072
# {'name': 'Algorithm', 'type': 'function'}                     0.000220
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              0.169282
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.000012
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.000392
#
#                                                     time (exc)_std  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                  0.000160
# {'name': 'Algorithm', 'type': 'function'}                 0.000019
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}          0.000012
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...        0.017678
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...        0.008339
#
#                                                     Machine clears_std  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.008508
# {'name': 'Algorithm', 'type': 'function'}                     0.014843
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              0.411439
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.003459
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.019788
#
#                                                                                time (exc)_percentiles  \
# node
# {'name': 'Base_Seq', 'type': 'function'}            [0.0070557499999999995, 0.007194000000000001, ...
# {'name': 'Algorithm', 'type': 'function'}                            [0.00058425, 0.000598, 0.000603]
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                    [0.00022325, 0.0002315, 0.000243]
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...  [1.29070175, 1.2940295000000002, 1.30458350000...
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                  [0.734351, 0.7368325, 0.74190975]
#
#                                                                        Machine clears_percentiles
# node
# {'name': 'Base_Seq', 'type': 'function'}                         [0.02044975, 0.027724, 0.032329]
# {'name': 'Algorithm', 'type': 'function'}           [0.00833475, 0.0127785, 0.019187000000000003]
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                                  [nan, nan, nan]
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...              [0.99564675, 0.9981475, 0.998563]
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...      [0.940767, 0.9530069999999999, 0.9630295]

# %% [markdown]
# #### Multi-Indexed Thicket Example
# Example will show how to pass a columnar joined thicket object. When passing a columnar joined thicket object, the columns argument will now take a list of tuples. Each tuple will consist of two elements. The first element will always be the column index, and the second element will be an associated column under the column index you passed.<br>
#
#  - Example: (column_index, column_name) -> ("GCC", "Machine clears")

# %%
metrics = [("Clang","time (exc)"),("GCC","Machine clears")]

# %%
th.percentiles(combined_th,columns=metrics)
combined_th.statsframe.dataframe.head(5)
# Out:
#                                                                               \
#                                                                         name
# node
# {'name': 'Base_Seq', 'type': 'function'}                            Base_Seq
# {'name': 'Algorithm', 'type': 'function'}                          Algorithm
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}            Algorithm_MEMCPY
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...  Algorithm_MEMCPY.default
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...  Algorithm_MEMCPY.library
#
#                                                             Clang  \
#                                                    time (exc)_max
# node
# {'name': 'Base_Seq', 'type': 'function'}                 0.007418
# {'name': 'Algorithm', 'type': 'function'}                0.000637
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}         0.000252
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...       1.343627
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...       0.756431
#
#                                                                     \
#                                                    time (exc)_mean
# node
# {'name': 'Base_Seq', 'type': 'function'}                  0.007147
# {'name': 'Algorithm', 'type': 'function'}                 0.000597
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}          0.000233
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...        1.298458
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...        0.738028
#
#                                                                       \
#                                                    time (exc)_median
# node
# {'name': 'Base_Seq', 'type': 'function'}                    0.007194
# {'name': 'Algorithm', 'type': 'function'}                   0.000598
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}            0.000231
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...          1.294030
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...          0.736833
#
#                                                                    \
#                                                    time (exc)_min
# node
# {'name': 'Base_Seq', 'type': 'function'}                 0.006875
# {'name': 'Algorithm', 'type': 'function'}                0.000564
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}         0.000215
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...       1.275210
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...       0.722036
#
#                                                                                                        \
#                                                                                time (exc)_percentiles
# node
# {'name': 'Base_Seq', 'type': 'function'}            [0.0070557499999999995, 0.007194000000000001, ...
# {'name': 'Algorithm', 'type': 'function'}                            [0.00058425, 0.000598, 0.000603]
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                    [0.00022325, 0.0002315, 0.000243]
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...  [1.29070175, 1.2940295000000002, 1.30458350000...
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                  [0.734351, 0.7368325, 0.74190975]
#
#                                                                    \
#                                                    time (exc)_std
# node
# {'name': 'Base_Seq', 'type': 'function'}                 0.000160
# {'name': 'Algorithm', 'type': 'function'}                0.000019
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}         0.000012
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...       0.017678
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...       0.008339
#
#                                                                    \
#                                                    time (exc)_var
# node
# {'name': 'Base_Seq', 'type': 'function'}             2.549456e-08
# {'name': 'Algorithm', 'type': 'function'}            3.652100e-10
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}     1.560100e-10
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...   3.125018e-04
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...   6.953802e-05
#
#                                                                   GCC  \
#                                                    Machine clears_max
# node
# {'name': 'Base_Seq', 'type': 'function'}                     0.034919
# {'name': 'Algorithm', 'type': 'function'}                    0.078947
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}             1.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...           0.998832
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...           0.978771
#
#                                                                         \
#                                                    Machine clears_mean
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.027250
# {'name': 'Algorithm', 'type': 'function'}                     0.019933
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              0.311366
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.996608
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.944047
#
#                                                                           \
#                                                    Machine clears_median
# node
# {'name': 'Base_Seq', 'type': 'function'}                        0.026362
# {'name': 'Algorithm', 'type': 'function'}                       0.012092
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                0.027067
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...              0.996824
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...              0.949658
#
#                                                                        \
#                                                    Machine clears_min
# node
# {'name': 'Base_Seq', 'type': 'function'}                     0.014810
# {'name': 'Algorithm', 'type': 'function'}                    0.000000
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}             0.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...           0.993177
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...           0.905950
#
#                                                                                                    \
#                                                                        Machine clears_percentiles
# node
# {'name': 'Base_Seq', 'type': 'function'}            [0.02477725, 0.026362499999999997, 0.0327565]
# {'name': 'Algorithm', 'type': 'function'}           [0.00871275, 0.012091999999999999, 0.0234505]
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                        [0.0, 0.027067, 0.764881]
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...   [0.99538975, 0.9968239999999999, 0.99820775]
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...              [0.9266765, 0.9496575, 0.9571795]
#
#                                                                        \
#                                                    Machine clears_std
# node
# {'name': 'Base_Seq', 'type': 'function'}                     0.005898
# {'name': 'Algorithm', 'type': 'function'}                    0.021524
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}             0.451230
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...           0.001797
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...           0.022419
#
#
#                                                    Machine clears_var
# node
# {'name': 'Base_Seq', 'type': 'function'}                     0.000035
# {'name': 'Algorithm', 'type': 'function'}                    0.000463
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}             0.203608
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...           0.000003
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...           0.000503

# %% [markdown]
# ### 5.8 Check Normality
#
# The `check_normality` function will determine if the data is normal or non-normal for each node in the performance data table. For this test, the more data the better. Perferably you would want to have 20 data points (20 files) in a dataset to have an accurate result. <br>
#
# A `True` boolean will be appended to the aggregated statistics table if the data is normal and a `False` boolean will be appended to the aggregated statistics table if the data is non-normal. The appended column will be denoted with `_normality` at the end of column name i.e. `column_normality`.

# %% [markdown]
# #### Single Index Thicket Example

# %%
metrics = ["time (exc)","Machine clears"]

# %%
th.check_normality(clang_th,columns=metrics)
clang_th.statsframe.dataframe.head(5)
# Out:
#                                                                         name  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                            Base_Seq
# {'name': 'Algorithm', 'type': 'function'}                          Algorithm
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}            Algorithm_MEMCPY
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...  Algorithm_MEMCPY.default
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...  Algorithm_MEMCPY.library
#
#                                                     time (exc)_max  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                  0.007418
# {'name': 'Algorithm', 'type': 'function'}                 0.000637
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}          0.000252
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...        1.343627
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...        0.756431
#
#                                                     Machine clears_max  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.044086
# {'name': 'Algorithm', 'type': 'function'}                     0.045977
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              1.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.998909
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.973024
#
#                                                     time (exc)_min  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                  0.006875
# {'name': 'Algorithm', 'type': 'function'}                 0.000564
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}          0.000215
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...        1.275210
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...        0.722036
#
#                                                     Machine clears_min  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.015849
# {'name': 'Algorithm', 'type': 'function'}                     0.004092
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              0.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.987818
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.906853
#
#                                                     time (exc)_median  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                     0.007194
# {'name': 'Algorithm', 'type': 'function'}                    0.000598
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}             0.000231
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...           1.294030
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...           0.736833
#
#                                                     Machine clears_median  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                         0.027724
# {'name': 'Algorithm', 'type': 'function'}                        0.012778
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                      NaN
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...               0.998147
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...               0.953007
#
#                                                     time (exc)_mean  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                   0.007147
# {'name': 'Algorithm', 'type': 'function'}                  0.000597
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}           0.000233
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...         1.298458
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...         0.738028
#
#                                                     Machine clears_mean  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                       0.027126
# {'name': 'Algorithm', 'type': 'function'}                      0.017969
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}               0.230749
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...             0.996256
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...             0.948031
#
#                                                     time (exc)_var  \
# node
# {'name': 'Base_Seq', 'type': 'function'}              2.549456e-08
# {'name': 'Algorithm', 'type': 'function'}             3.652100e-10
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}      1.560100e-10
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...    3.125018e-04
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...    6.953802e-05
#
#                                                     Machine clears_var  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.000072
# {'name': 'Algorithm', 'type': 'function'}                     0.000220
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              0.169282
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.000012
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.000392
#
#                                                     time (exc)_std  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                  0.000160
# {'name': 'Algorithm', 'type': 'function'}                 0.000019
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}          0.000012
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...        0.017678
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...        0.008339
#
#                                                     Machine clears_std  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.008508
# {'name': 'Algorithm', 'type': 'function'}                     0.014843
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              0.411439
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.003459
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.019788
#
#                                                                                time (exc)_percentiles  \
# node
# {'name': 'Base_Seq', 'type': 'function'}            [0.0070557499999999995, 0.007194000000000001, ...
# {'name': 'Algorithm', 'type': 'function'}                            [0.00058425, 0.000598, 0.000603]
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                    [0.00022325, 0.0002315, 0.000243]
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...  [1.29070175, 1.2940295000000002, 1.30458350000...
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                  [0.734351, 0.7368325, 0.74190975]
#
#                                                                        Machine clears_percentiles  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                         [0.02044975, 0.027724, 0.032329]
# {'name': 'Algorithm', 'type': 'function'}           [0.00833475, 0.0127785, 0.019187000000000003]
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                                  [nan, nan, nan]
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...              [0.99564675, 0.9981475, 0.998563]
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...      [0.940767, 0.9530069999999999, 0.9630295]
#
#                                                    time (exc)_normality  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                           True
# {'name': 'Algorithm', 'type': 'function'}                          True
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                   True
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...                 True
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                 True
#
#                                                    Machine clears_normality
# node
# {'name': 'Base_Seq', 'type': 'function'}                               True
# {'name': 'Algorithm', 'type': 'function'}                             False
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                       True
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...                    False
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                     True

# %% [markdown]
# #### Multi-Indexed Thicket Example
# Example will show how to pass a columnar joined thicket object. When passing a columnar joined thicket object, the columns argument will now take a list of tuples. Each tuple will consist of two elements. The first element will always be the column index, and the second element will be an associated column under the column index you passed.<br>
#
#  - Example: (column_index, column_name) -> ("GCC", "Machine clears")

# %%
metrics = [("Clang","time (exc)"),("GCC","Machine clears")]

# %%
th.check_normality(combined_th,columns=metrics)
combined_th.statsframe.dataframe.head(5)
# Out:
#                                                                               \
#                                                                         name
# node
# {'name': 'Base_Seq', 'type': 'function'}                            Base_Seq
# {'name': 'Algorithm', 'type': 'function'}                          Algorithm
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}            Algorithm_MEMCPY
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...  Algorithm_MEMCPY.default
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...  Algorithm_MEMCPY.library
#
#                                                             Clang  \
#                                                    time (exc)_max
# node
# {'name': 'Base_Seq', 'type': 'function'}                 0.007418
# {'name': 'Algorithm', 'type': 'function'}                0.000637
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}         0.000252
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...       1.343627
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...       0.756431
#
#                                                                     \
#                                                    time (exc)_mean
# node
# {'name': 'Base_Seq', 'type': 'function'}                  0.007147
# {'name': 'Algorithm', 'type': 'function'}                 0.000597
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}          0.000233
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...        1.298458
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...        0.738028
#
#                                                                       \
#                                                    time (exc)_median
# node
# {'name': 'Base_Seq', 'type': 'function'}                    0.007194
# {'name': 'Algorithm', 'type': 'function'}                   0.000598
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}            0.000231
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...          1.294030
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...          0.736833
#
#                                                                    \
#                                                    time (exc)_min
# node
# {'name': 'Base_Seq', 'type': 'function'}                 0.006875
# {'name': 'Algorithm', 'type': 'function'}                0.000564
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}         0.000215
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...       1.275210
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...       0.722036
#
#                                                                          \
#                                                    time (exc)_normality
# node
# {'name': 'Base_Seq', 'type': 'function'}                           True
# {'name': 'Algorithm', 'type': 'function'}                          True
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                   True
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...                 True
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                 True
#
#                                                                                                        \
#                                                                                time (exc)_percentiles
# node
# {'name': 'Base_Seq', 'type': 'function'}            [0.0070557499999999995, 0.007194000000000001, ...
# {'name': 'Algorithm', 'type': 'function'}                            [0.00058425, 0.000598, 0.000603]
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                    [0.00022325, 0.0002315, 0.000243]
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...  [1.29070175, 1.2940295000000002, 1.30458350000...
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                  [0.734351, 0.7368325, 0.74190975]
#
#                                                                    \
#                                                    time (exc)_std
# node
# {'name': 'Base_Seq', 'type': 'function'}                 0.000160
# {'name': 'Algorithm', 'type': 'function'}                0.000019
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}         0.000012
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...       0.017678
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...       0.008339
#
#                                                                    \
#                                                    time (exc)_var
# node
# {'name': 'Base_Seq', 'type': 'function'}             2.549456e-08
# {'name': 'Algorithm', 'type': 'function'}            3.652100e-10
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}     1.560100e-10
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...   3.125018e-04
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...   6.953802e-05
#
#                                                                   GCC  \
#                                                    Machine clears_max
# node
# {'name': 'Base_Seq', 'type': 'function'}                     0.034919
# {'name': 'Algorithm', 'type': 'function'}                    0.078947
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}             1.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...           0.998832
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...           0.978771
#
#                                                                         \
#                                                    Machine clears_mean
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.027250
# {'name': 'Algorithm', 'type': 'function'}                     0.019933
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              0.311366
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.996608
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.944047
#
#                                                                           \
#                                                    Machine clears_median
# node
# {'name': 'Base_Seq', 'type': 'function'}                        0.026362
# {'name': 'Algorithm', 'type': 'function'}                       0.012092
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                0.027067
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...              0.996824
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...              0.949658
#
#                                                                        \
#                                                    Machine clears_min
# node
# {'name': 'Base_Seq', 'type': 'function'}                     0.014810
# {'name': 'Algorithm', 'type': 'function'}                    0.000000
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}             0.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...           0.993177
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...           0.905950
#
#                                                                              \
#                                                    Machine clears_normality
# node
# {'name': 'Base_Seq', 'type': 'function'}                               True
# {'name': 'Algorithm', 'type': 'function'}                             False
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                      False
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...                     True
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                     True
#
#                                                                                                    \
#                                                                        Machine clears_percentiles
# node
# {'name': 'Base_Seq', 'type': 'function'}            [0.02477725, 0.026362499999999997, 0.0327565]
# {'name': 'Algorithm', 'type': 'function'}           [0.00871275, 0.012091999999999999, 0.0234505]
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                        [0.0, 0.027067, 0.764881]
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...   [0.99538975, 0.9968239999999999, 0.99820775]
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...              [0.9266765, 0.9496575, 0.9571795]
#
#                                                                        \
#                                                    Machine clears_std
# node
# {'name': 'Base_Seq', 'type': 'function'}                     0.005898
# {'name': 'Algorithm', 'type': 'function'}                    0.021524
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}             0.451230
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...           0.001797
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...           0.022419
#
#
#                                                    Machine clears_var
# node
# {'name': 'Base_Seq', 'type': 'function'}                     0.000035
# {'name': 'Algorithm', 'type': 'function'}                    0.000463
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}             0.203608
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...           0.000003
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...           0.000503

# %% [markdown]
# ### 5.9 Nodewise Correlation
#
# The `correlation_nodewise` function will perform nodewise correlation for each node in the performance data table. <br>
#
# The correlation values will be appended to the aggregated statistics table and will be denoted with `correlation type` where `correlation type` can be `{pearson, spearman, kendall}`. <br>
#
# When working with a multi-indexed thicket (columnar join) a new column index will be created titled: `Union statistics`. See the **Multi-Indexed Thicket Example** to see the implementation of this.

# %% [markdown]
# #### Single Index Thicket Example

# %%
th.correlation_nodewise(clang_th,column1="time (exc)",column2="Machine clears",correlation="spearman")

# %%
clang_th.statsframe.dataframe.head(5)
# Out:
#                                                                         name  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                            Base_Seq
# {'name': 'Algorithm', 'type': 'function'}                          Algorithm
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}            Algorithm_MEMCPY
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...  Algorithm_MEMCPY.default
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...  Algorithm_MEMCPY.library
#
#                                                     time (exc)_max  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                  0.007418
# {'name': 'Algorithm', 'type': 'function'}                 0.000637
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}          0.000252
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...        1.343627
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...        0.756431
#
#                                                     Machine clears_max  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.044086
# {'name': 'Algorithm', 'type': 'function'}                     0.045977
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              1.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.998909
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.973024
#
#                                                     time (exc)_min  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                  0.006875
# {'name': 'Algorithm', 'type': 'function'}                 0.000564
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}          0.000215
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...        1.275210
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...        0.722036
#
#                                                     Machine clears_min  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.015849
# {'name': 'Algorithm', 'type': 'function'}                     0.004092
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              0.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.987818
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.906853
#
#                                                     time (exc)_median  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                     0.007194
# {'name': 'Algorithm', 'type': 'function'}                    0.000598
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}             0.000231
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...           1.294030
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...           0.736833
#
#                                                     Machine clears_median  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                         0.027724
# {'name': 'Algorithm', 'type': 'function'}                        0.012778
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                      NaN
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...               0.998147
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...               0.953007
#
#                                                     time (exc)_mean  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                   0.007147
# {'name': 'Algorithm', 'type': 'function'}                  0.000597
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}           0.000233
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...         1.298458
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...         0.738028
#
#                                                     Machine clears_mean  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                       0.027126
# {'name': 'Algorithm', 'type': 'function'}                      0.017969
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}               0.230749
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...             0.996256
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...             0.948031
#
#                                                     time (exc)_var  \
# node
# {'name': 'Base_Seq', 'type': 'function'}              2.549456e-08
# {'name': 'Algorithm', 'type': 'function'}             3.652100e-10
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}      1.560100e-10
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...    3.125018e-04
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...    6.953802e-05
#
#                                                     Machine clears_var  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.000072
# {'name': 'Algorithm', 'type': 'function'}                     0.000220
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              0.169282
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.000012
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.000392
#
#                                                     time (exc)_std  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                  0.000160
# {'name': 'Algorithm', 'type': 'function'}                 0.000019
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}          0.000012
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...        0.017678
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...        0.008339
#
#                                                     Machine clears_std  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.008508
# {'name': 'Algorithm', 'type': 'function'}                     0.014843
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              0.411439
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.003459
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.019788
#
#                                                                                time (exc)_percentiles  \
# node
# {'name': 'Base_Seq', 'type': 'function'}            [0.0070557499999999995, 0.007194000000000001, ...
# {'name': 'Algorithm', 'type': 'function'}                            [0.00058425, 0.000598, 0.000603]
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                    [0.00022325, 0.0002315, 0.000243]
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...  [1.29070175, 1.2940295000000002, 1.30458350000...
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                  [0.734351, 0.7368325, 0.74190975]
#
#                                                                        Machine clears_percentiles  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                         [0.02044975, 0.027724, 0.032329]
# {'name': 'Algorithm', 'type': 'function'}           [0.00833475, 0.0127785, 0.019187000000000003]
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                                  [nan, nan, nan]
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...              [0.99564675, 0.9981475, 0.998563]
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...      [0.940767, 0.9530069999999999, 0.9630295]
#
#                                                    time (exc)_normality  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                           True
# {'name': 'Algorithm', 'type': 'function'}                          True
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                   True
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...                 True
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                 True
#
#                                                    Machine clears_normality  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                               True
# {'name': 'Algorithm', 'type': 'function'}                             False
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                       True
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...                    False
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                     True
#
#                                                     time (exc)_vs_Machine clears spearman
# node
# {'name': 'Base_Seq', 'type': 'function'}                                        -0.248485
# {'name': 'Algorithm', 'type': 'function'}                                       -0.182372
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                                      NaN
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...                              -0.066667
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                              -0.163636

# %% [markdown]
# #### Multi-Indexed Thicket Example
#
# Example will show how to pass a columnar joined thicket object. When passing a columnar joined thicket object, the columns argument will now take a list of tuples. Each tuple will consist of two elements. The first element will always be the column index, and the second element will be an associated column under the column index you passed.<br>
#
#  - Example: (column_index, column_name) -> ("GCC", "Machine clears")

# %%
th.correlation_nodewise(combined_th,column1=("Clang","time (exc)"),column2=("GCC","Machine clears"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 th.correlation_nodewise(combined_th,column1=("Clang","time (exc)"),column2=("GCC","Machine clears"))
#
# File ~/opt/anaconda3/envs/llnl-dev/lib/python3.8/site-packages/thicket/stats/correlation_nodewise.py:81, in correlation_nodewise(thicket, column1, column2, correlation)
#      78 for node in thicket.statsframe.dataframe.index.tolist():
#      79     if correlation == "pearson":
#      80         correlated.append(
# ---> 81             stats.pearsonr(
#      82                 thicket.dataframe.loc[node][column1],
#      83                 thicket.dataframe.loc[node][column2],
#      84             )[0]
#      85         )
#      86     elif correlation == "spearman":
#      87         correlated.append(
#      88             stats.spearmanr(
#      89                 thicket.dataframe.loc[node][column1],
#      90                 thicket.dataframe.loc[node][column2],
#      91             )[0]
#      92         )
#
# File ~/opt/anaconda3/envs/llnl-dev/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4452, in pearsonr(x, y, alternative)
#    4448 # Unlike np.linalg.norm or the expression sqrt((xm*xm).sum()),
#    4449 # scipy.linalg.norm(xm) does not overflow if xm is, for example,
#    4450 # [-5e210, 5e210, 3e200, -3e200]
#    4451 normxm = linalg.norm(xm)
# -> 4452 normym = linalg.norm(ym)
#    4454 threshold = 1e-13
#    4455 if normxm < threshold*abs(xmean) or normym < threshold*abs(ymean):
#    4456     # If all the values in x (likewise y) are very close to the mean,
#    4457     # the loss of precision that occurs in the subtraction xm = x - xmean
#    4458     # might result in large errors in r.
#
# File ~/opt/anaconda3/envs/llnl-dev/lib/python3.8/site-packages/scipy/linalg/_misc.py:146, in norm(a, ord, axis, keepdims, check_finite)
#     144 # Differs from numpy only in non-finite handling and the use of blas.
#     145 if check_finite:
# --> 146     a = np.asarray_chkfinite(a)
#     147 else:
#     148     a = np.asarray(a)
#
# File ~/opt/anaconda3/envs/llnl-dev/lib/python3.8/site-packages/numpy/lib/function_base.py:628, in asarray_chkfinite(a, dtype, order)
#     626 a = asarray(a, dtype=dtype, order=order)
#     627 if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 628     raise ValueError(
#     629         "array must not contain infs or NaNs")
#     630 return a
#
# ValueError: array must not contain infs or NaNs

# %%
combined_th.statsframe.dataframe

# %% [markdown]
# ### 5.10 Calculate Boxplot
#
# The `calc_boxplot_statistics` function will calculate a boxplots `{q1, q2, q3, iqr, lowerfence, upperfence}` for each node in the performance data table. <br>
#
# Each column will have the values: `{q1,q2,q3,iqr,lowerfence, upperfence}` calculated. The appended columns to the aggregated statistics table will be denoted with either col + `{_q1, _q2, _q3,_iqr, _lowerfence, _upperfence}`. <br>
#
# Lastly, `calc_boxplot_statistics` will calculate outliers as well. The outliers will be appended to the aggregated statistics table and denoted with `_outliers` at the end of the column name i.e. `column_outliers`.

# %% [markdown]
# #### Single Indexed Thicket

# %%
metrics = ["time (exc)", "Machine clears"]

# %%
th.calc_boxplot_statistics(clang_th,columns = metrics)
clang_th.statsframe.dataframe.head(5)
# Out:
#                                                                         name  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                            Base_Seq
# {'name': 'Algorithm', 'type': 'function'}                          Algorithm
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}            Algorithm_MEMCPY
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...  Algorithm_MEMCPY.default
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...  Algorithm_MEMCPY.library
#
#                                                     time (exc)_max  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                  0.007418
# {'name': 'Algorithm', 'type': 'function'}                 0.000637
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}          0.000252
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...        1.343627
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...        0.756431
#
#                                                     Machine clears_max  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.044086
# {'name': 'Algorithm', 'type': 'function'}                     0.045977
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              1.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.998909
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.973024
#
#                                                     time (exc)_min  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                  0.006875
# {'name': 'Algorithm', 'type': 'function'}                 0.000564
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}          0.000215
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...        1.275210
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...        0.722036
#
#                                                     Machine clears_min  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.015849
# {'name': 'Algorithm', 'type': 'function'}                     0.004092
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              0.000000
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.987818
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.906853
#
#                                                     time (exc)_median  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                     0.007194
# {'name': 'Algorithm', 'type': 'function'}                    0.000598
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}             0.000231
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...           1.294030
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...           0.736833
#
#                                                     Machine clears_median  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                         0.027724
# {'name': 'Algorithm', 'type': 'function'}                        0.012778
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                      NaN
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...               0.998147
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...               0.953007
#
#                                                     time (exc)_mean  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                   0.007147
# {'name': 'Algorithm', 'type': 'function'}                  0.000597
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}           0.000233
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...         1.298458
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...         0.738028
#
#                                                     Machine clears_mean  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                       0.027126
# {'name': 'Algorithm', 'type': 'function'}                      0.017969
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}               0.230749
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...             0.996256
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...             0.948031
#
#                                                     time (exc)_var  \
# node
# {'name': 'Base_Seq', 'type': 'function'}              2.549456e-08
# {'name': 'Algorithm', 'type': 'function'}             3.652100e-10
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}      1.560100e-10
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...    3.125018e-04
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...    6.953802e-05
#
#                                                     Machine clears_var  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.000072
# {'name': 'Algorithm', 'type': 'function'}                     0.000220
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              0.169282
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.000012
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.000392
#
#                                                     time (exc)_std  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                  0.000160
# {'name': 'Algorithm', 'type': 'function'}                 0.000019
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}          0.000012
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...        0.017678
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...        0.008339
#
#                                                     Machine clears_std  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                      0.008508
# {'name': 'Algorithm', 'type': 'function'}                     0.014843
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}              0.411439
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            0.003459
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            0.019788
#
#                                                                                time (exc)_percentiles  \
# node
# {'name': 'Base_Seq', 'type': 'function'}            [0.0070557499999999995, 0.007194000000000001, ...
# {'name': 'Algorithm', 'type': 'function'}                            [0.00058425, 0.000598, 0.000603]
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                    [0.00022325, 0.0002315, 0.000243]
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...  [1.29070175, 1.2940295000000002, 1.30458350000...
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                  [0.734351, 0.7368325, 0.74190975]
#
#                                                                        Machine clears_percentiles  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                         [0.02044975, 0.027724, 0.032329]
# {'name': 'Algorithm', 'type': 'function'}           [0.00833475, 0.0127785, 0.019187000000000003]
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                                  [nan, nan, nan]
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...              [0.99564675, 0.9981475, 0.998563]
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...      [0.940767, 0.9530069999999999, 0.9630295]
#
#                                                    time (exc)_normality  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                           True
# {'name': 'Algorithm', 'type': 'function'}                          True
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                   True
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...                 True
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                 True
#
#                                                    Machine clears_normality  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                               True
# {'name': 'Algorithm', 'type': 'function'}                             False
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                       True
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...                    False
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                     True
#
#                                                     time (exc)_vs_Machine clears spearman  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                                        -0.248485
# {'name': 'Algorithm', 'type': 'function'}                                       -0.182372
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                                      NaN
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...                              -0.066667
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                              -0.163636
#
#                                                     time (exc)_q1(0.25, 0.5, 0.75)  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                                  0.007056
# {'name': 'Algorithm', 'type': 'function'}                                 0.000584
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                          0.000223
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...                        1.290702
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                        0.734351
#
#                                                     time (exc)_q2(0.25, 0.5, 0.75)  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                                  0.007194
# {'name': 'Algorithm', 'type': 'function'}                                 0.000598
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                          0.000231
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...                        1.294030
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                        0.736833
#
#                                                     time (exc)_q3(0.25, 0.5, 0.75)  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                                  0.007235
# {'name': 'Algorithm', 'type': 'function'}                                 0.000603
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                          0.000243
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...                        1.304584
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                        0.741910
#
#                                                     time (exc)_iqr(0.25, 0.5, 0.75)  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                                   0.000180
# {'name': 'Algorithm', 'type': 'function'}                                  0.000019
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                           0.000020
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...                         0.013882
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                         0.007559
#
#                                                     time (exc)_lowerfence(0.25, 0.5, 0.75)  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                                          0.006786
# {'name': 'Algorithm', 'type': 'function'}                                         0.000556
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                                  0.000194
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...                                1.269879
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                                0.723013
#
#                                                     time (exc)_upperfence(0.25, 0.5, 0.75)  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                                          0.007505
# {'name': 'Algorithm', 'type': 'function'}                                         0.000631
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                                  0.000273
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...                                1.325406
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                                0.753248
#
#                                                            time (exc)_outliers(0.25, 0.5, 0.75)  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                                                     []
# {'name': 'Algorithm', 'type': 'function'}                                [-6215258077338487992]
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                                             []
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...                       [-5209312886849177138]
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...  [-6215258077338487992, 2952880866756432583]
#
#                                                     Machine clears_q1(0.25, 0.5, 0.75)  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                                      0.020450
# {'name': 'Algorithm', 'type': 'function'}                                     0.008335
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                                   NaN
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...                            0.995647
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                            0.940767
#
#                                                     Machine clears_q2(0.25, 0.5, 0.75)  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                                      0.027724
# {'name': 'Algorithm', 'type': 'function'}                                     0.012778
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                                   NaN
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...                            0.998147
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                            0.953007
#
#                                                     Machine clears_q3(0.25, 0.5, 0.75)  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                                      0.032329
# {'name': 'Algorithm', 'type': 'function'}                                     0.019187
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                                   NaN
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...                            0.998563
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                            0.963029
#
#                                                     Machine clears_iqr(0.25, 0.5, 0.75)  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                                       0.011879
# {'name': 'Algorithm', 'type': 'function'}                                      0.010852
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                                    NaN
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...                             0.002916
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                             0.022262
#
#                                                     Machine clears_lowerfence(0.25, 0.5, 0.75)  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                                              0.002631
# {'name': 'Algorithm', 'type': 'function'}                                            -0.007944
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                                           NaN
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...                                    0.991272
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                                    0.907373
#
#                                                     Machine clears_upperfence(0.25, 0.5, 0.75)  \
# node
# {'name': 'Base_Seq', 'type': 'function'}                                              0.050148
# {'name': 'Algorithm', 'type': 'function'}                                             0.035465
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                                           NaN
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...                                    1.002937
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                                    0.996423
#
#                                                         Machine clears_outliers(0.25, 0.5, 0.75)
# node
# {'name': 'Base_Seq', 'type': 'function'}                                                      []
# {'name': 'Algorithm', 'type': 'function'}           [-3599056568737907663, -1052581724128069964]
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                                              []
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...                        [-3471411573597426176]
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                         [2152740489414885744]

# %% [markdown]
# #### Multi-indexed Thicket
# Example will show how to pass a columnar joined thicket object. When passing a columnar joined thicket object, the columns argument will now take a list of tuples. Each tuple will consist of two elements. The first element will always be the column index, and the second element will be an associated column under the column index you passed.<br>
#
#  - Example: (column_index, column_name) -> ("GCC", "Machine clears")

# %%
metrics = [("Clang","time (exc)"),("GCC","Machine clears")]

# %%
th.calc_boxplot_statistics(combined_th,columns = metrics)
combined_th.statsframe.dataframe.head(5)
# Out:
#                                                                                         \
#                                                                                   name
# node
# {'name': 'Base_Seq', 'type': 'function'}                                      Base_Seq
# {'name': 'Algorithm', 'type': 'function'}                                    Algorithm
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                      Algorithm_MEMCPY
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...            Algorithm_MEMCPY.default
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...            Algorithm_MEMCPY.library
# {'name': 'Algorithm_MEMSET', 'type': 'function'}                      Algorithm_MEMSET
# {'name': 'Algorithm_MEMSET.default', 'type': 'f...            Algorithm_MEMSET.default
# {'name': 'Algorithm_MEMSET.library', 'type': 'f...            Algorithm_MEMSET.library
# {'name': 'Algorithm_REDUCE_SUM', 'type': 'funct...                Algorithm_REDUCE_SUM
# {'name': 'Algorithm_REDUCE_SUM.default', 'type'...        Algorithm_REDUCE_SUM.default
# {'name': 'Algorithm_SCAN', 'type': 'function'}                          Algorithm_SCAN
# {'name': 'Algorithm_SCAN.default', 'type': 'fun...              Algorithm_SCAN.default
# {'name': 'Algorithm_SORT', 'type': 'function'}                          Algorithm_SORT
# {'name': 'Algorithm_SORT.default', 'type': 'fun...              Algorithm_SORT.default
# {'name': 'Algorithm_SORTPAIRS', 'type': 'functi...                 Algorithm_SORTPAIRS
# {'name': 'Algorithm_SORTPAIRS.default', 'type':...         Algorithm_SORTPAIRS.default
# {'name': 'Apps', 'type': 'function'}                                              Apps
# {'name': 'Apps_CONVECTION3DPA', 'type': 'functi...                 Apps_CONVECTION3DPA
# {'name': 'Apps_CONVECTION3DPA.default', 'type':...         Apps_CONVECTION3DPA.default
# {'name': 'Apps_DEL_DOT_VEC_2D', 'type': 'functi...                 Apps_DEL_DOT_VEC_2D
# {'name': 'Apps_DEL_DOT_VEC_2D.default', 'type':...         Apps_DEL_DOT_VEC_2D.default
# {'name': 'Apps_DIFFUSION3DPA', 'type': 'function'}                  Apps_DIFFUSION3DPA
# {'name': 'Apps_DIFFUSION3DPA.default', 'type': ...          Apps_DIFFUSION3DPA.default
# {'name': 'Apps_ENERGY', 'type': 'function'}                                Apps_ENERGY
# {'name': 'Apps_ENERGY.default', 'type': 'functi...                 Apps_ENERGY.default
# {'name': 'Apps_FIR', 'type': 'function'}                                      Apps_FIR
# {'name': 'Apps_FIR.default', 'type': 'function'}                      Apps_FIR.default
# {'name': 'Apps_HALOEXCHANGE', 'type': 'function'}                    Apps_HALOEXCHANGE
# {'name': 'Apps_HALOEXCHANGE.default', 'type': '...           Apps_HALOEXCHANGE.default
# {'name': 'Apps_HALOEXCHANGE_FUSED', 'type': 'fu...             Apps_HALOEXCHANGE_FUSED
# {'name': 'Apps_HALOEXCHANGE_FUSED.default', 'ty...     Apps_HALOEXCHANGE_FUSED.default
# {'name': 'Apps_LTIMES', 'type': 'function'}                                Apps_LTIMES
# {'name': 'Apps_LTIMES.default', 'type': 'functi...                 Apps_LTIMES.default
# {'name': 'Apps_LTIMES_NOVIEW', 'type': 'function'}                  Apps_LTIMES_NOVIEW
# {'name': 'Apps_LTIMES_NOVIEW.default', 'type': ...          Apps_LTIMES_NOVIEW.default
# {'name': 'Apps_MASS3DPA', 'type': 'function'}                            Apps_MASS3DPA
# {'name': 'Apps_MASS3DPA.default', 'type': 'func...               Apps_MASS3DPA.default
# {'name': 'Apps_NODAL_ACCUMULATION_3D', 'type': ...          Apps_NODAL_ACCUMULATION_3D
# {'name': 'Apps_NODAL_ACCUMULATION_3D.default', ...  Apps_NODAL_ACCUMULATION_3D.default
# {'name': 'Apps_PRESSURE', 'type': 'function'}                            Apps_PRESSURE
# {'name': 'Apps_PRESSURE.default', 'type': 'func...               Apps_PRESSURE.default
# {'name': 'Apps_VOL3D', 'type': 'function'}                                  Apps_VOL3D
# {'name': 'Apps_VOL3D.default', 'type': 'function'}                  Apps_VOL3D.default
# {'name': 'Basic', 'type': 'function'}                                            Basic
# {'name': 'Basic_DAXPY', 'type': 'function'}                                Basic_DAXPY
# {'name': 'Basic_DAXPY.default', 'type': 'functi...                 Basic_DAXPY.default
# {'name': 'Basic_DAXPY_ATOMIC', 'type': 'function'}                  Basic_DAXPY_ATOMIC
# {'name': 'Basic_DAXPY_ATOMIC.default', 'type': ...          Basic_DAXPY_ATOMIC.default
# {'name': 'Basic_IF_QUAD', 'type': 'function'}                            Basic_IF_QUAD
# {'name': 'Basic_IF_QUAD.default', 'type': 'func...               Basic_IF_QUAD.default
# {'name': 'Basic_INDEXLIST', 'type': 'function'}                        Basic_INDEXLIST
# {'name': 'Basic_INDEXLIST.default', 'type': 'fu...             Basic_INDEXLIST.default
# {'name': 'Basic_INDEXLIST_3LOOP', 'type': 'func...               Basic_INDEXLIST_3LOOP
# {'name': 'Basic_INDEXLIST_3LOOP.default', 'type...       Basic_INDEXLIST_3LOOP.default
# {'name': 'Basic_INIT3', 'type': 'function'}                                Basic_INIT3
# {'name': 'Basic_INIT3.default', 'type': 'functi...                 Basic_INIT3.default
# {'name': 'Basic_INIT_VIEW1D', 'type': 'function'}                    Basic_INIT_VIEW1D
# {'name': 'Basic_INIT_VIEW1D.default', 'type': '...           Basic_INIT_VIEW1D.default
# {'name': 'Basic_INIT_VIEW1D_OFFSET', 'type': 'f...            Basic_INIT_VIEW1D_OFFSET
# {'name': 'Basic_INIT_VIEW1D_OFFSET.default', 't...    Basic_INIT_VIEW1D_OFFSET.default
# {'name': 'Basic_MAT_MAT_SHARED', 'type': 'funct...                Basic_MAT_MAT_SHARED
# {'name': 'Basic_MAT_MAT_SHARED.default', 'type'...        Basic_MAT_MAT_SHARED.default
# {'name': 'Basic_MULADDSUB', 'type': 'function'}                        Basic_MULADDSUB
# {'name': 'Basic_MULADDSUB.default', 'type': 'fu...             Basic_MULADDSUB.default
# {'name': 'Basic_NESTED_INIT', 'type': 'function'}                    Basic_NESTED_INIT
# {'name': 'Basic_NESTED_INIT.default', 'type': '...           Basic_NESTED_INIT.default
# {'name': 'Basic_PI_ATOMIC', 'type': 'function'}                        Basic_PI_ATOMIC
# {'name': 'Basic_PI_ATOMIC.default', 'type': 'fu...             Basic_PI_ATOMIC.default
# {'name': 'Basic_PI_REDUCE', 'type': 'function'}                        Basic_PI_REDUCE
# {'name': 'Basic_PI_REDUCE.default', 'type': 'fu...             Basic_PI_REDUCE.default
# {'name': 'Basic_REDUCE3_INT', 'type': 'function'}                    Basic_REDUCE3_INT
# {'name': 'Basic_REDUCE3_INT.default', 'type': '...           Basic_REDUCE3_INT.default
# {'name': 'Basic_REDUCE_STRUCT', 'type': 'functi...                 Basic_REDUCE_STRUCT
# {'name': 'Basic_REDUCE_STRUCT.default', 'type':...         Basic_REDUCE_STRUCT.default
# {'name': 'Basic_TRAP_INT', 'type': 'function'}                          Basic_TRAP_INT
# {'name': 'Basic_TRAP_INT.default', 'type': 'fun...              Basic_TRAP_INT.default
# {'name': 'Lcals', 'type': 'function'}                                            Lcals
# {'name': 'Lcals_DIFF_PREDICT', 'type': 'function'}                  Lcals_DIFF_PREDICT
# {'name': 'Lcals_DIFF_PREDICT.default', 'type': ...          Lcals_DIFF_PREDICT.default
# {'name': 'Lcals_EOS', 'type': 'function'}                                    Lcals_EOS
# {'name': 'Lcals_EOS.default', 'type': 'function'}                    Lcals_EOS.default
# {'name': 'Lcals_FIRST_DIFF', 'type': 'function'}                      Lcals_FIRST_DIFF
# {'name': 'Lcals_FIRST_DIFF.default', 'type': 'f...            Lcals_FIRST_DIFF.default
# {'name': 'Lcals_FIRST_MIN', 'type': 'function'}                        Lcals_FIRST_MIN
# {'name': 'Lcals_FIRST_MIN.default', 'type': 'fu...             Lcals_FIRST_MIN.default
# {'name': 'Lcals_FIRST_SUM', 'type': 'function'}                        Lcals_FIRST_SUM
# {'name': 'Lcals_FIRST_SUM.default', 'type': 'fu...             Lcals_FIRST_SUM.default
# {'name': 'Lcals_GEN_LIN_RECUR', 'type': 'functi...                 Lcals_GEN_LIN_RECUR
# {'name': 'Lcals_GEN_LIN_RECUR.default', 'type':...         Lcals_GEN_LIN_RECUR.default
# {'name': 'Lcals_HYDRO_1D', 'type': 'function'}                          Lcals_HYDRO_1D
# {'name': 'Lcals_HYDRO_1D.default', 'type': 'fun...              Lcals_HYDRO_1D.default
# {'name': 'Lcals_HYDRO_2D', 'type': 'function'}                          Lcals_HYDRO_2D
# {'name': 'Lcals_HYDRO_2D.default', 'type': 'fun...              Lcals_HYDRO_2D.default
# {'name': 'Lcals_INT_PREDICT', 'type': 'function'}                    Lcals_INT_PREDICT
# {'name': 'Lcals_INT_PREDICT.default', 'type': '...           Lcals_INT_PREDICT.default
# {'name': 'Lcals_PLANCKIAN', 'type': 'function'}                        Lcals_PLANCKIAN
# {'name': 'Lcals_PLANCKIAN.default', 'type': 'fu...             Lcals_PLANCKIAN.default
# {'name': 'Lcals_TRIDIAG_ELIM', 'type': 'function'}                  Lcals_TRIDIAG_ELIM
# {'name': 'Lcals_TRIDIAG_ELIM.default', 'type': ...          Lcals_TRIDIAG_ELIM.default
# {'name': 'Polybench', 'type': 'function'}                                    Polybench
# {'name': 'Polybench_2MM', 'type': 'function'}                            Polybench_2MM
# {'name': 'Polybench_2MM.default', 'type': 'func...               Polybench_2MM.default
# {'name': 'Polybench_3MM', 'type': 'function'}                            Polybench_3MM
# {'name': 'Polybench_3MM.default', 'type': 'func...               Polybench_3MM.default
# {'name': 'Polybench_ADI', 'type': 'function'}                            Polybench_ADI
# {'name': 'Polybench_ADI.default', 'type': 'func...               Polybench_ADI.default
# {'name': 'Polybench_ATAX', 'type': 'function'}                          Polybench_ATAX
# {'name': 'Polybench_ATAX.default', 'type': 'fun...              Polybench_ATAX.default
# {'name': 'Polybench_FDTD_2D', 'type': 'function'}                    Polybench_FDTD_2D
# {'name': 'Polybench_FDTD_2D.default', 'type': '...           Polybench_FDTD_2D.default
# {'name': 'Polybench_FLOYD_WARSHALL', 'type': 'f...            Polybench_FLOYD_WARSHALL
# {'name': 'Polybench_FLOYD_WARSHALL.default', 't...    Polybench_FLOYD_WARSHALL.default
# {'name': 'Polybench_GEMM', 'type': 'function'}                          Polybench_GEMM
# {'name': 'Polybench_GEMM.default', 'type': 'fun...              Polybench_GEMM.default
# {'name': 'Polybench_GEMVER', 'type': 'function'}                      Polybench_GEMVER
# {'name': 'Polybench_GEMVER.default', 'type': 'f...            Polybench_GEMVER.default
# {'name': 'Polybench_GESUMMV', 'type': 'function'}                    Polybench_GESUMMV
# {'name': 'Polybench_GESUMMV.default', 'type': '...           Polybench_GESUMMV.default
# {'name': 'Polybench_HEAT_3D', 'type': 'function'}                    Polybench_HEAT_3D
# {'name': 'Polybench_HEAT_3D.default', 'type': '...           Polybench_HEAT_3D.default
# {'name': 'Polybench_JACOBI_1D', 'type': 'functi...                 Polybench_JACOBI_1D
# {'name': 'Polybench_JACOBI_1D.default', 'type':...         Polybench_JACOBI_1D.default
# {'name': 'Polybench_JACOBI_2D', 'type': 'functi...                 Polybench_JACOBI_2D
# {'name': 'Polybench_JACOBI_2D.default', 'type':...         Polybench_JACOBI_2D.default
# {'name': 'Polybench_MVT', 'type': 'function'}                            Polybench_MVT
# {'name': 'Polybench_MVT.default', 'type': 'func...               Polybench_MVT.default
# {'name': 'Stream', 'type': 'function'}                                          Stream
# {'name': 'Stream_ADD', 'type': 'function'}                                  Stream_ADD
# {'name': 'Stream_ADD.default', 'type': 'function'}                  Stream_ADD.default
# {'name': 'Stream_COPY', 'type': 'function'}                                Stream_COPY
# {'name': 'Stream_COPY.default', 'type': 'functi...                 Stream_COPY.default
# {'name': 'Stream_DOT', 'type': 'function'}                                  Stream_DOT
# {'name': 'Stream_DOT.default', 'type': 'function'}                  Stream_DOT.default
# {'name': 'Stream_MUL', 'type': 'function'}                                  Stream_MUL
# {'name': 'Stream_MUL.default', 'type': 'function'}                  Stream_MUL.default
# {'name': 'Stream_TRIAD', 'type': 'function'}                              Stream_TRIAD
# {'name': 'Stream_TRIAD.default', 'type': 'funct...                Stream_TRIAD.default
#
#                                                                              Clang  \
#                                                    time (exc)_iqr(0.25, 0.5, 0.75)
# node
# {'name': 'Base_Seq', 'type': 'function'}                                  0.000180
# {'name': 'Algorithm', 'type': 'function'}                                 0.000019
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                          0.000020
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...                        0.013882
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                        0.007559
# {'name': 'Algorithm_MEMSET', 'type': 'function'}                          0.000012
# {'name': 'Algorithm_MEMSET.default', 'type': 'f...                        0.011281
# {'name': 'Algorithm_MEMSET.library', 'type': 'f...                        0.010607
# {'name': 'Algorithm_REDUCE_SUM', 'type': 'funct...                        0.000018
# {'name': 'Algorithm_REDUCE_SUM.default', 'type'...                        0.000842
# {'name': 'Algorithm_SCAN', 'type': 'function'}                            0.000013
# {'name': 'Algorithm_SCAN.default', 'type': 'fun...                        0.049911
# {'name': 'Algorithm_SORT', 'type': 'function'}                            0.000031
# {'name': 'Algorithm_SORT.default', 'type': 'fun...                        0.325242
# {'name': 'Algorithm_SORTPAIRS', 'type': 'functi...                        0.000019
# {'name': 'Algorithm_SORTPAIRS.default', 'type':...                        0.486854
# {'name': 'Apps', 'type': 'function'}                                      0.000023
# {'name': 'Apps_CONVECTION3DPA', 'type': 'functi...                        0.000031
# {'name': 'Apps_CONVECTION3DPA.default', 'type':...                        0.248319
# {'name': 'Apps_DEL_DOT_VEC_2D', 'type': 'functi...                        0.000024
# {'name': 'Apps_DEL_DOT_VEC_2D.default', 'type':...                        0.162293
# {'name': 'Apps_DIFFUSION3DPA', 'type': 'function'}                        0.000017
# {'name': 'Apps_DIFFUSION3DPA.default', 'type': ...                        0.360592
# {'name': 'Apps_ENERGY', 'type': 'function'}                               0.000013
# {'name': 'Apps_ENERGY.default', 'type': 'functi...                        0.156343
# {'name': 'Apps_FIR', 'type': 'function'}                                  0.000013
# {'name': 'Apps_FIR.default', 'type': 'function'}                          0.362092
# {'name': 'Apps_HALOEXCHANGE', 'type': 'function'}                         0.000015
# {'name': 'Apps_HALOEXCHANGE.default', 'type': '...                        0.001543
# {'name': 'Apps_HALOEXCHANGE_FUSED', 'type': 'fu...                        0.000014
# {'name': 'Apps_HALOEXCHANGE_FUSED.default', 'ty...                        0.001742
# {'name': 'Apps_LTIMES', 'type': 'function'}                               0.000032
# {'name': 'Apps_LTIMES.default', 'type': 'functi...                        0.015430
# {'name': 'Apps_LTIMES_NOVIEW', 'type': 'function'}                        0.000024
# {'name': 'Apps_LTIMES_NOVIEW.default', 'type': ...                        0.495016
# {'name': 'Apps_MASS3DPA', 'type': 'function'}                             0.000027
# {'name': 'Apps_MASS3DPA.default', 'type': 'func...                        0.267754
# {'name': 'Apps_NODAL_ACCUMULATION_3D', 'type': ...                        0.000018
# {'name': 'Apps_NODAL_ACCUMULATION_3D.default', ...                        0.348039
# {'name': 'Apps_PRESSURE', 'type': 'function'}                             0.000011
# {'name': 'Apps_PRESSURE.default', 'type': 'func...                        0.257885
# {'name': 'Apps_VOL3D', 'type': 'function'}                                0.000020
# {'name': 'Apps_VOL3D.default', 'type': 'function'}                        0.306443
# {'name': 'Basic', 'type': 'function'}                                     0.000031
# {'name': 'Basic_DAXPY', 'type': 'function'}                               0.000018
# {'name': 'Basic_DAXPY.default', 'type': 'functi...                        0.069035
# {'name': 'Basic_DAXPY_ATOMIC', 'type': 'function'}                        0.000025
# {'name': 'Basic_DAXPY_ATOMIC.default', 'type': ...                        0.036887
# {'name': 'Basic_IF_QUAD', 'type': 'function'}                             0.000029
# {'name': 'Basic_IF_QUAD.default', 'type': 'func...                        0.309119
# {'name': 'Basic_INDEXLIST', 'type': 'function'}                           0.000007
# {'name': 'Basic_INDEXLIST.default', 'type': 'fu...                        0.007459
# {'name': 'Basic_INDEXLIST_3LOOP', 'type': 'func...                        0.000006
# {'name': 'Basic_INDEXLIST_3LOOP.default', 'type...                        0.011856
# {'name': 'Basic_INIT3', 'type': 'function'}                               0.000006
# {'name': 'Basic_INIT3.default', 'type': 'functi...                        0.249191
# {'name': 'Basic_INIT_VIEW1D', 'type': 'function'}                         0.000005
# {'name': 'Basic_INIT_VIEW1D.default', 'type': '...                        0.055781
# {'name': 'Basic_INIT_VIEW1D_OFFSET', 'type': 'f...                        0.000015
# {'name': 'Basic_INIT_VIEW1D_OFFSET.default', 't...                        0.173127
# {'name': 'Basic_MAT_MAT_SHARED', 'type': 'funct...                        0.000015
# {'name': 'Basic_MAT_MAT_SHARED.default', 'type'...                        0.296799
# {'name': 'Basic_MULADDSUB', 'type': 'function'}                           0.000012
# {'name': 'Basic_MULADDSUB.default', 'type': 'fu...                        0.094100
# {'name': 'Basic_NESTED_INIT', 'type': 'function'}                         0.000005
# {'name': 'Basic_NESTED_INIT.default', 'type': '...                        0.107445
# {'name': 'Basic_PI_ATOMIC', 'type': 'function'}                           0.000006
# {'name': 'Basic_PI_ATOMIC.default', 'type': 'fu...                        0.006131
# {'name': 'Basic_PI_REDUCE', 'type': 'function'}                           0.000007
# {'name': 'Basic_PI_REDUCE.default', 'type': 'fu...                        0.040822
# {'name': 'Basic_REDUCE3_INT', 'type': 'function'}                         0.000005
# {'name': 'Basic_REDUCE3_INT.default', 'type': '...                        0.005274
# {'name': 'Basic_REDUCE_STRUCT', 'type': 'functi...                        0.000010
# {'name': 'Basic_REDUCE_STRUCT.default', 'type':...                        0.035571
# {'name': 'Basic_TRAP_INT', 'type': 'function'}                            0.000008
# {'name': 'Basic_TRAP_INT.default', 'type': 'fun...                        0.100760
# {'name': 'Lcals', 'type': 'function'}                                     0.000011
# {'name': 'Lcals_DIFF_PREDICT', 'type': 'function'}                        0.000016
# {'name': 'Lcals_DIFF_PREDICT.default', 'type': ...                        1.276178
# {'name': 'Lcals_EOS', 'type': 'function'}                                 0.000011
# {'name': 'Lcals_EOS.default', 'type': 'function'}                         0.076795
# {'name': 'Lcals_FIRST_DIFF', 'type': 'function'}                          0.000004
# {'name': 'Lcals_FIRST_DIFF.default', 'type': 'f...                        0.129560
# {'name': 'Lcals_FIRST_MIN', 'type': 'function'}                           0.000005
# {'name': 'Lcals_FIRST_MIN.default', 'type': 'fu...                        0.010094
# {'name': 'Lcals_FIRST_SUM', 'type': 'function'}                           0.000027
# {'name': 'Lcals_FIRST_SUM.default', 'type': 'fu...                        0.297483
# {'name': 'Lcals_GEN_LIN_RECUR', 'type': 'functi...                        0.000009
# {'name': 'Lcals_GEN_LIN_RECUR.default', 'type':...                        0.235150
# {'name': 'Lcals_HYDRO_1D', 'type': 'function'}                            0.000019
# {'name': 'Lcals_HYDRO_1D.default', 'type': 'fun...                        0.199540
# {'name': 'Lcals_HYDRO_2D', 'type': 'function'}                            0.000028
# {'name': 'Lcals_HYDRO_2D.default', 'type': 'fun...                        0.220843
# {'name': 'Lcals_INT_PREDICT', 'type': 'function'}                         0.000015
# {'name': 'Lcals_INT_PREDICT.default', 'type': '...                        0.483285
# {'name': 'Lcals_PLANCKIAN', 'type': 'function'}                           0.000010
# {'name': 'Lcals_PLANCKIAN.default', 'type': 'fu...                        0.299238
# {'name': 'Lcals_TRIDIAG_ELIM', 'type': 'function'}                        0.000014
# {'name': 'Lcals_TRIDIAG_ELIM.default', 'type': ...                        0.520481
# {'name': 'Polybench', 'type': 'function'}                                 0.000025
# {'name': 'Polybench_2MM', 'type': 'function'}                             0.000026
# {'name': 'Polybench_2MM.default', 'type': 'func...                        5.371676
# {'name': 'Polybench_3MM', 'type': 'function'}                             0.000011
# {'name': 'Polybench_3MM.default', 'type': 'func...                        5.312385
# {'name': 'Polybench_ADI', 'type': 'function'}                             0.000026
# {'name': 'Polybench_ADI.default', 'type': 'func...                        0.151934
# {'name': 'Polybench_ATAX', 'type': 'function'}                            0.000004
# {'name': 'Polybench_ATAX.default', 'type': 'fun...                        0.292794
# {'name': 'Polybench_FDTD_2D', 'type': 'function'}                         0.000018
# {'name': 'Polybench_FDTD_2D.default', 'type': '...                        0.169164
# {'name': 'Polybench_FLOYD_WARSHALL', 'type': 'f...                        0.000005
# {'name': 'Polybench_FLOYD_WARSHALL.default', 't...                        5.998318
# {'name': 'Polybench_GEMM', 'type': 'function'}                            0.000021
# {'name': 'Polybench_GEMM.default', 'type': 'fun...                        2.024892
# {'name': 'Polybench_GEMVER', 'type': 'function'}                          0.000009
# {'name': 'Polybench_GEMVER.default', 'type': 'f...                        0.111251
# {'name': 'Polybench_GESUMMV', 'type': 'function'}                         0.000012
# {'name': 'Polybench_GESUMMV.default', 'type': '...                        0.064882
# {'name': 'Polybench_HEAT_3D', 'type': 'function'}                         0.000006
# {'name': 'Polybench_HEAT_3D.default', 'type': '...                        0.261605
# {'name': 'Polybench_JACOBI_1D', 'type': 'functi...                        0.000019
# {'name': 'Polybench_JACOBI_1D.default', 'type':...                        0.468344
# {'name': 'Polybench_JACOBI_2D', 'type': 'functi...                        0.000005
# {'name': 'Polybench_JACOBI_2D.default', 'type':...                        0.638859
# {'name': 'Polybench_MVT', 'type': 'function'}                             0.000017
# {'name': 'Polybench_MVT.default', 'type': 'func...                        0.044062
# {'name': 'Stream', 'type': 'function'}                                    0.000012
# {'name': 'Stream_ADD', 'type': 'function'}                                0.000023
# {'name': 'Stream_ADD.default', 'type': 'function'}                        0.218484
# {'name': 'Stream_COPY', 'type': 'function'}                               0.000036
# {'name': 'Stream_COPY.default', 'type': 'functi...                        0.241431
# {'name': 'Stream_DOT', 'type': 'function'}                                0.000013
# {'name': 'Stream_DOT.default', 'type': 'function'}                        0.236161
# {'name': 'Stream_MUL', 'type': 'function'}                                0.000039
# {'name': 'Stream_MUL.default', 'type': 'function'}                        0.270679
# {'name': 'Stream_TRIAD', 'type': 'function'}                              0.000009
# {'name': 'Stream_TRIAD.default', 'type': 'funct...                        0.317395
#
#                                                                                            \
#                                                    time (exc)_lowerfence(0.25, 0.5, 0.75)
# node
# {'name': 'Base_Seq', 'type': 'function'}                                         0.006786
# {'name': 'Algorithm', 'type': 'function'}                                        0.000556
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}                                 0.000194
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...                               1.269879
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...                               0.723013
# {'name': 'Algorithm_MEMSET', 'type': 'function'}                                 0.000210
# {'name': 'Algorithm_MEMSET.default', 'type': 'f...                               0.747860
# {'name': 'Algorithm_MEMSET.library', 'type': 'f...                               0.749752
# {'name': 'Algorithm_REDUCE_SUM', 'type': 'funct...                               0.000086
# {'name': 'Algorithm_REDUCE_SUM.default', 'type'...                               0.434612
# {'name': 'Algorithm_SCAN', 'type': 'function'}                                   0.000096
# {'name': 'Algorithm_SCAN.default', 'type': 'fun...                               1.179962
# {'name': 'Algorithm_SORT', 'type': 'function'}                                   0.000069
# {'name': 'Algorithm_SORT.default', 'type': 'fun...                              14.039902
# {'name': 'Algorithm_SORTPAIRS', 'type': 'functi...                               0.000088
# {'name': 'Algorithm_SORTPAIRS.default', 'type':...                              16.468742
# {'name': 'Apps', 'type': 'function'}                                             0.000901
# {'name': 'Apps_CONVECTION3DPA', 'type': 'functi...                               0.000079
# {'name': 'Apps_CONVECTION3DPA.default', 'type':...                               3.980518
# {'name': 'Apps_DEL_DOT_VEC_2D', 'type': 'functi...                               0.000086
# {'name': 'Apps_DEL_DOT_VEC_2D.default', 'type':...                               8.771401
# {'name': 'Apps_DIFFUSION3DPA', 'type': 'function'}                               0.000102
# {'name': 'Apps_DIFFUSION3DPA.default', 'type': ...                               8.514256
# {'name': 'Apps_ENERGY', 'type': 'function'}                                      0.000100
# {'name': 'Apps_ENERGY.default', 'type': 'functi...                              18.416663
# {'name': 'Apps_FIR', 'type': 'function'}                                         0.000101
# {'name': 'Apps_FIR.default', 'type': 'function'}                                 9.138748
# {'name': 'Apps_HALOEXCHANGE', 'type': 'function'}                                0.000065
# {'name': 'Apps_HALOEXCHANGE.default', 'type': '...                               0.146543
# {'name': 'Apps_HALOEXCHANGE_FUSED', 'type': 'fu...                               0.000066
# {'name': 'Apps_HALOEXCHANGE_FUSED.default', 'ty...                               0.146095
# {'name': 'Apps_LTIMES', 'type': 'function'}                                      0.000063
# {'name': 'Apps_LTIMES.default', 'type': 'functi...                               7.629016
# {'name': 'Apps_LTIMES_NOVIEW', 'type': 'function'}                               0.000082
# {'name': 'Apps_LTIMES_NOVIEW.default', 'type': ...                               6.907569
# {'name': 'Apps_MASS3DPA', 'type': 'function'}                                    0.000078
# {'name': 'Apps_MASS3DPA.default', 'type': 'func...                               2.479579
# {'name': 'Apps_NODAL_ACCUMULATION_3D', 'type': ...                               0.000091
# {'name': 'Apps_NODAL_ACCUMULATION_3D.default', ...                               4.774216
# {'name': 'Apps_PRESSURE', 'type': 'function'}                                    0.000131
# {'name': 'Apps_PRESSURE.default', 'type': 'func...                              24.944436
# {'name': 'Apps_VOL3D', 'type': 'function'}                                       0.000108
# {'name': 'Apps_VOL3D.default', 'type': 'function'}                              12.593461
# {'name': 'Basic', 'type': 'function'}                                            0.001098
# {'name': 'Basic_DAXPY', 'type': 'function'}                                      0.000104
# {'name': 'Basic_DAXPY.default', 'type': 'functi...                               6.401461
# {'name': 'Basic_DAXPY_ATOMIC', 'type': 'function'}                               0.000086
# {'name': 'Basic_DAXPY_ATOMIC.default', 'type': ...                               6.462392
# {'name': 'Basic_IF_QUAD', 'type': 'function'}                                    0.000084
# {'name': 'Basic_IF_QUAD.default', 'type': 'func...                              11.653120
# {'name': 'Basic_INDEXLIST', 'type': 'function'}                                  0.000110
# {'name': 'Basic_INDEXLIST.default', 'type': 'fu...                               3.830912
# {'name': 'Basic_INDEXLIST_3LOOP', 'type': 'func...                               0.000115
# {'name': 'Basic_INDEXLIST_3LOOP.default', 'type...                               5.251268
# {'name': 'Basic_INIT3', 'type': 'function'}                                      0.000136
# {'name': 'Basic_INIT3.default', 'type': 'functi...                              18.208446
# {'name': 'Basic_INIT_VIEW1D', 'type': 'function'}                                0.000112
# {'name': 'Basic_INIT_VIEW1D.default', 'type': '...                              19.198393
# {'name': 'Basic_INIT_VIEW1D_OFFSET', 'type': 'f...                               0.000130
# {'name': 'Basic_INIT_VIEW1D_OFFSET.default', 't...                              18.888405
# {'name': 'Basic_MAT_MAT_SHARED', 'type': 'funct...                               0.000132
# {'name': 'Basic_MAT_MAT_SHARED.default', 'type'...                              49.121915
# {'name': 'Basic_MULADDSUB', 'type': 'function'}                                  0.000101
# {'name': 'Basic_MULADDSUB.default', 'type': 'fu...                              13.420787
# {'name': 'Basic_NESTED_INIT', 'type': 'function'}                                0.000111
# {'name': 'Basic_NESTED_INIT.default', 'type': '...                               7.477108
# {'name': 'Basic_PI_ATOMIC', 'type': 'function'}                                  0.000070
# {'name': 'Basic_PI_ATOMIC.default', 'type': 'fu...                               0.568108
# {'name': 'Basic_PI_REDUCE', 'type': 'function'}                                  0.000070
# {'name': 'Basic_PI_REDUCE.default', 'type': 'fu...                               0.516019
# {'name': 'Basic_REDUCE3_INT', 'type': 'function'}                                0.000075
# {'name': 'Basic_REDUCE3_INT.default', 'type': '...                               0.128034
# {'name': 'Basic_REDUCE_STRUCT', 'type': 'functi...                               0.000100
# {'name': 'Basic_REDUCE_STRUCT.default', 'type':...                               0.711054
# {'name': 'Basic_TRAP_INT', 'type': 'function'}                                   0.000069
# {'name': 'Basic_TRAP_INT.default', 'type': 'fun...                               1.408403
# {'name': 'Lcals', 'type': 'function'}                                            0.000791
# {'name': 'Lcals_DIFF_PREDICT', 'type': 'function'}                               0.000126
# {'name': 'Lcals_DIFF_PREDICT.default', 'type': ...                             142.872250
# {'name': 'Lcals_EOS', 'type': 'function'}                                        0.000100
# {'name': 'Lcals_EOS.default', 'type': 'function'}                               11.323971
# {'name': 'Lcals_FIRST_DIFF', 'type': 'function'}                                 0.000112
# {'name': 'Lcals_FIRST_DIFF.default', 'type': 'f...                              25.697880
# {'name': 'Lcals_FIRST_MIN', 'type': 'function'}                                  0.000106
# {'name': 'Lcals_FIRST_MIN.default', 'type': 'fu...                               1.181292
# {'name': 'Lcals_FIRST_SUM', 'type': 'function'}                                  0.000086
# {'name': 'Lcals_FIRST_SUM.default', 'type': 'fu...                              25.187714
# {'name': 'Lcals_GEN_LIN_RECUR', 'type': 'functi...                               0.000109
# {'name': 'Lcals_GEN_LIN_RECUR.default', 'type':...                              24.001823
# {'name': 'Lcals_HYDRO_1D', 'type': 'function'}                                   0.000106
# {'name': 'Lcals_HYDRO_1D.default', 'type': 'fun...                              17.833563
# {'name': 'Lcals_HYDRO_2D', 'type': 'function'}                                   0.000095
# {'name': 'Lcals_HYDRO_2D.default', 'type': 'fun...                              14.006248
# {'name': 'Lcals_INT_PREDICT', 'type': 'function'}                                0.000137
# {'name': 'Lcals_INT_PREDICT.default', 'type': '...                              31.299476
# {'name': 'Lcals_PLANCKIAN', 'type': 'function'}                                  0.000102
# {'name': 'Lcals_PLANCKIAN.default', 'type': 'fu...                               7.412036
# {'name': 'Lcals_TRIDIAG_ELIM', 'type': 'function'}                               0.000105
# {'name': 'Lcals_TRIDIAG_ELIM.default', 'type': ...                              22.410697
# {'name': 'Polybench', 'type': 'function'}                                        0.000918
# {'name': 'Polybench_2MM', 'type': 'function'}                                    0.000118
# {'name': 'Polybench_2MM.default', 'type': 'func...                             255.090098
# {'name': 'Polybench_3MM', 'type': 'function'}                                    0.000138
# {'name': 'Polybench_3MM.default', 'type': 'func...                             272.327651
# {'name': 'Polybench_ADI', 'type': 'function'}                                    0.000078
# {'name': 'Polybench_ADI.default', 'type': 'func...                               4.289150
# {'name': 'Polybench_ATAX', 'type': 'function'}                                   0.000101
# {'name': 'Polybench_ATAX.default', 'type': 'fun...                               4.366053
# {'name': 'Polybench_FDTD_2D', 'type': 'function'}                                0.000123
# {'name': 'Polybench_FDTD_2D.default', 'type': '...                              13.812407
# {'name': 'Polybench_FLOYD_WARSHALL', 'type': 'f...                               0.000152
# {'name': 'Polybench_FLOYD_WARSHALL.default', 't...                             293.360100
# {'name': 'Polybench_GEMM', 'type': 'function'}                                   0.000114
# {'name': 'Polybench_GEMM.default', 'type': 'fun...                              50.155365
# {'name': 'Polybench_GEMVER', 'type': 'function'}                                 0.000092
# {'name': 'Polybench_GEMVER.default', 'type': 'f...                               0.962447
# {'name': 'Polybench_GESUMMV', 'type': 'function'}                                0.000099
# {'name': 'Polybench_GESUMMV.default', 'type': '...                               1.244510
# {'name': 'Polybench_HEAT_3D', 'type': 'function'}                                0.000103
# {'name': 'Polybench_HEAT_3D.default', 'type': '...                              13.037420
# {'name': 'Polybench_JACOBI_1D', 'type': 'functi...                               0.000103
# {'name': 'Polybench_JACOBI_1D.default', 'type':...                              40.282247
# {'name': 'Polybench_JACOBI_2D', 'type': 'functi...                               0.000144
# {'name': 'Polybench_JACOBI_2D.default', 'type':...                              55.421506
# {'name': 'Polybench_MVT', 'type': 'function'}                                    0.000097
# {'name': 'Polybench_MVT.default', 'type': 'func...                               4.447017
# {'name': 'Stream', 'type': 'function'}                                           0.000344
# {'name': 'Stream_ADD', 'type': 'function'}                                       0.000089
# {'name': 'Stream_ADD.default', 'type': 'function'}                              17.751151
# {'name': 'Stream_COPY', 'type': 'function'}                                      0.000077
# {'name': 'Stream_COPY.default', 'type': 'functi...                              22.976006
# {'name': 'Stream_DOT', 'type': 'function'}                                       0.000098
# {'name': 'Stream_DOT.default', 'type': 'function'}                              21.250147
# {'name': 'Stream_MUL', 'type': 'function'}                                       0.000076
# {'name': 'Stream_MUL.default', 'type': 'function'}                              22.906514
# {'name': 'Stream_TRIAD', 'type': 'function'}                                     0.000097
# {'name': 'Stream_TRIAD.default', 'type': 'funct...                              17.587227
#
#                                                                    \
#                                                    time (exc)_max
# node
# {'name': 'Base_Seq', 'type': 'function'}                 0.007418
# {'name': 'Algorithm', 'type': 'function'}                0.000637
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}         0.000252
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...       1.343627
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...       0.756431
# {'name': 'Algorithm_MEMSET', 'type': 'function'}         0.000245
# {'name': 'Algorithm_MEMSET.default', 'type': 'f...       0.793649
# {'name': 'Algorithm_MEMSET.library', 'type': 'f...       0.796325
# {'name': 'Algorithm_REDUCE_SUM', 'type': 'funct...       0.000134
# {'name': 'Algorithm_REDUCE_SUM.default', 'type'...       0.489614
# {'name': 'Algorithm_SCAN', 'type': 'function'}           0.000139
# {'name': 'Algorithm_SCAN.default', 'type': 'fun...       1.309478
# {'name': 'Algorithm_SORT', 'type': 'function'}           0.000149
# {'name': 'Algorithm_SORT.default', 'type': 'fun...      14.921879
# {'name': 'Algorithm_SORTPAIRS', 'type': 'functi...       0.000181
# {'name': 'Algorithm_SORTPAIRS.default', 'type':...      17.888402
# {'name': 'Apps', 'type': 'function'}                     0.000972
# {'name': 'Apps_CONVECTION3DPA', 'type': 'functi...       0.000175
# {'name': 'Apps_CONVECTION3DPA.default', 'type':...       4.942184
# {'name': 'Apps_DEL_DOT_VEC_2D', 'type': 'functi...       0.000157
# {'name': 'Apps_DEL_DOT_VEC_2D.default', 'type':...       9.387266
# {'name': 'Apps_DIFFUSION3DPA', 'type': 'function'}       0.000162
# {'name': 'Apps_DIFFUSION3DPA.default', 'type': ...       9.836065
# {'name': 'Apps_ENERGY', 'type': 'function'}              0.000175
# {'name': 'Apps_ENERGY.default', 'type': 'functi...      18.841716
# {'name': 'Apps_FIR', 'type': 'function'}                 0.000145
# {'name': 'Apps_FIR.default', 'type': 'function'}        10.314075
# {'name': 'Apps_HALOEXCHANGE', 'type': 'function'}        0.000130
# {'name': 'Apps_HALOEXCHANGE.default', 'type': '...       0.159063
# {'name': 'Apps_HALOEXCHANGE_FUSED', 'type': 'fu...       0.000112
# {'name': 'Apps_HALOEXCHANGE_FUSED.default', 'ty...       0.158483
# {'name': 'Apps_LTIMES', 'type': 'function'}              0.000147
# {'name': 'Apps_LTIMES.default', 'type': 'functi...       8.264255
# {'name': 'Apps_LTIMES_NOVIEW', 'type': 'function'}       0.000155
# {'name': 'Apps_LTIMES_NOVIEW.default', 'type': ...       8.350809
# {'name': 'Apps_MASS3DPA', 'type': 'function'}            0.000171
# {'name': 'Apps_MASS3DPA.default', 'type': 'func...       3.376522
# {'name': 'Apps_NODAL_ACCUMULATION_3D', 'type': ...       0.000144
# {'name': 'Apps_NODAL_ACCUMULATION_3D.default', ...       5.817402
# {'name': 'Apps_PRESSURE', 'type': 'function'}            0.000169
# {'name': 'Apps_PRESSURE.default', 'type': 'func...      25.853309
# {'name': 'Apps_VOL3D', 'type': 'function'}               0.000172
# {'name': 'Apps_VOL3D.default', 'type': 'function'}      13.853235
# {'name': 'Basic', 'type': 'function'}                    0.001261
# {'name': 'Basic_DAXPY', 'type': 'function'}              0.000164
# {'name': 'Basic_DAXPY.default', 'type': 'functi...       6.680694
# {'name': 'Basic_DAXPY_ATOMIC', 'type': 'function'}       0.000190
# {'name': 'Basic_DAXPY_ATOMIC.default', 'type': ...       6.660024
# {'name': 'Basic_IF_QUAD', 'type': 'function'}            0.000170
# {'name': 'Basic_IF_QUAD.default', 'type': 'func...      12.603683
# {'name': 'Basic_INDEXLIST', 'type': 'function'}          0.000148
# {'name': 'Basic_INDEXLIST.default', 'type': 'fu...       3.913221
# {'name': 'Basic_INDEXLIST_3LOOP', 'type': 'func...       0.000146
# {'name': 'Basic_INDEXLIST_3LOOP.default', 'type...       5.561280
# {'name': 'Basic_INIT3', 'type': 'function'}              0.000158
# {'name': 'Basic_INIT3.default', 'type': 'functi...      18.874580
# {'name': 'Basic_INIT_VIEW1D', 'type': 'function'}        0.000182
# {'name': 'Basic_INIT_VIEW1D.default', 'type': '...      19.352615
# {'name': 'Basic_INIT_VIEW1D_OFFSET', 'type': 'f...       0.000169
# {'name': 'Basic_INIT_VIEW1D_OFFSET.default', 't...      19.438861
# {'name': 'Basic_MAT_MAT_SHARED', 'type': 'funct...       0.000182
# {'name': 'Basic_MAT_MAT_SHARED.default', 'type'...      50.258750
# {'name': 'Basic_MULADDSUB', 'type': 'function'}          0.000138
# {'name': 'Basic_MULADDSUB.default', 'type': 'fu...      13.948391
# {'name': 'Basic_NESTED_INIT', 'type': 'function'}        0.000126
# {'name': 'Basic_NESTED_INIT.default', 'type': '...       7.822246
# {'name': 'Basic_PI_ATOMIC', 'type': 'function'}          0.000087
# {'name': 'Basic_PI_ATOMIC.default', 'type': 'fu...       0.678549
# {'name': 'Basic_PI_REDUCE', 'type': 'function'}          0.000090
# {'name': 'Basic_PI_REDUCE.default', 'type': 'fu...       0.638159
# {'name': 'Basic_REDUCE3_INT', 'type': 'function'}        0.000098
# {'name': 'Basic_REDUCE3_INT.default', 'type': '...       0.167228
# {'name': 'Basic_REDUCE_STRUCT', 'type': 'functi...       0.000144
# {'name': 'Basic_REDUCE_STRUCT.default', 'type':...       0.924569
# {'name': 'Basic_TRAP_INT', 'type': 'function'}           0.000094
# {'name': 'Basic_TRAP_INT.default', 'type': 'fun...       1.909272
# {'name': 'Lcals', 'type': 'function'}                    0.000827
# {'name': 'Lcals_DIFF_PREDICT', 'type': 'function'}       0.000210
# {'name': 'Lcals_DIFF_PREDICT.default', 'type': ...     146.834402
# {'name': 'Lcals_EOS', 'type': 'function'}                0.000135
# {'name': 'Lcals_EOS.default', 'type': 'function'}       11.693958
# {'name': 'Lcals_FIRST_DIFF', 'type': 'function'}         0.000127
# {'name': 'Lcals_FIRST_DIFF.default', 'type': 'f...      26.074381
# {'name': 'Lcals_FIRST_MIN', 'type': 'function'}          0.000122
# {'name': 'Lcals_FIRST_MIN.default', 'type': 'fu...       1.298284
# {'name': 'Lcals_FIRST_SUM', 'type': 'function'}          0.000227
# {'name': 'Lcals_FIRST_SUM.default', 'type': 'fu...      31.516097
# {'name': 'Lcals_GEN_LIN_RECUR', 'type': 'functi...       0.000162
# {'name': 'Lcals_GEN_LIN_RECUR.default', 'type':...      24.692555
# {'name': 'Lcals_HYDRO_1D', 'type': 'function'}           0.000280
# {'name': 'Lcals_HYDRO_1D.default', 'type': 'fun...      18.431287
# {'name': 'Lcals_HYDRO_2D', 'type': 'function'}           0.000224
# {'name': 'Lcals_HYDRO_2D.default', 'type': 'fun...      16.116536
# {'name': 'Lcals_INT_PREDICT', 'type': 'function'}        0.000205
# {'name': 'Lcals_INT_PREDICT.default', 'type': '...      32.593097
# {'name': 'Lcals_PLANCKIAN', 'type': 'function'}          0.000156
# {'name': 'Lcals_PLANCKIAN.default', 'type': 'fu...       8.349696
# {'name': 'Lcals_TRIDIAG_ELIM', 'type': 'function'}       0.000189
# {'name': 'Lcals_TRIDIAG_ELIM.default', 'type': ...      26.484884
# {'name': 'Polybench', 'type': 'function'}                0.000990
# {'name': 'Polybench_2MM', 'type': 'function'}            0.000198
# {'name': 'Polybench_2MM.default', 'type': 'func...     271.518454
# {'name': 'Polybench_3MM', 'type': 'function'}            0.000302
# {'name': 'Polybench_3MM.default', 'type': 'func...     287.168774
# {'name': 'Polybench_ADI', 'type': 'function'}            0.000148
# {'name': 'Polybench_ADI.default', 'type': 'func...       4.774396
# {'name': 'Polybench_ATAX', 'type': 'function'}           0.000122
# {'name': 'Polybench_ATAX.default', 'type': 'fun...       5.173798
# {'name': 'Polybench_FDTD_2D', 'type': 'function'}        0.000177
# {'name': 'Polybench_FDTD_2D.default', 'type': '...      14.314280
# {'name': 'Polybench_FLOYD_WARSHALL', 'type': 'f...       0.000171
# {'name': 'Polybench_FLOYD_WARSHALL.default', 't...     326.633466
# {'name': 'Polybench_GEMM', 'type': 'function'}           0.000299
# {'name': 'Polybench_GEMM.default', 'type': 'fun...      56.396219
# {'name': 'Polybench_GEMVER', 'type': 'function'}         0.000154
# {'name': 'Polybench_GEMVER.default', 'type': 'f...       1.265162
# {'name': 'Polybench_GESUMMV', 'type': 'function'}        0.000140
# {'name': 'Polybench_GESUMMV.default', 'type': '...       1.458382
# {'name': 'Polybench_HEAT_3D', 'type': 'function'}        0.000150
# {'name': 'Polybench_HEAT_3D.default', 'type': '...      13.818999
# {'name': 'Polybench_JACOBI_1D', 'type': 'functi...       0.000175
# {'name': 'Polybench_JACOBI_1D.default', 'type':...      41.580827
# {'name': 'Polybench_JACOBI_2D', 'type': 'functi...       0.000166
# {'name': 'Polybench_JACOBI_2D.default', 'type':...      57.417497
# {'name': 'Polybench_MVT', 'type': 'function'}            0.000145
# {'name': 'Polybench_MVT.default', 'type': 'func...       4.591794
# {'name': 'Stream', 'type': 'function'}                   0.000390
# {'name': 'Stream_ADD', 'type': 'function'}               0.000161
# {'name': 'Stream_ADD.default', 'type': 'function'}      18.446698
# {'name': 'Stream_COPY', 'type': 'function'}              0.000175
# {'name': 'Stream_COPY.default', 'type': 'functi...      23.813291
# {'name': 'Stream_DOT', 'type': 'function'}               0.000153
# {'name': 'Stream_DOT.default', 'type': 'function'}      21.909119
# {'name': 'Stream_MUL', 'type': 'function'}               0.000183
# {'name': 'Stream_MUL.default', 'type': 'function'}      23.707915
# {'name': 'Stream_TRIAD', 'type': 'function'}             0.000160
# {'name': 'Stream_TRIAD.default', 'type': 'funct...      18.470533
#
#                                                                     \
#                                                    time (exc)_mean
# node
# {'name': 'Base_Seq', 'type': 'function'}                  0.007147
# {'name': 'Algorithm', 'type': 'function'}                 0.000597
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}          0.000233
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...        1.298458
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...        0.738028
# {'name': 'Algorithm_MEMSET', 'type': 'function'}          0.000235
# ...
# {'name': 'Lcals', 'type': 'function'}                                                0.058468
# {'name': 'Lcals_DIFF_PREDICT', 'type': 'function'}                                        NaN
# {'name': 'Lcals_DIFF_PREDICT.default', 'type': ...                                   0.999999
# {'name': 'Lcals_EOS', 'type': 'function'}                                                 NaN
# {'name': 'Lcals_EOS.default', 'type': 'function'}                                    1.000668
# {'name': 'Lcals_FIRST_DIFF', 'type': 'function'}                                          NaN
# {'name': 'Lcals_FIRST_DIFF.default', 'type': 'f...                                   0.999142
# {'name': 'Lcals_FIRST_MIN', 'type': 'function'}                                           NaN
# {'name': 'Lcals_FIRST_MIN.default', 'type': 'fu...                                   1.010578
# {'name': 'Lcals_FIRST_SUM', 'type': 'function'}                                           NaN
# {'name': 'Lcals_FIRST_SUM.default', 'type': 'fu...                                   0.999187
# {'name': 'Lcals_GEN_LIN_RECUR', 'type': 'functi...                                        NaN
# {'name': 'Lcals_GEN_LIN_RECUR.default', 'type':...                                   0.999462
# {'name': 'Lcals_HYDRO_1D', 'type': 'function'}                                            NaN
# {'name': 'Lcals_HYDRO_1D.default', 'type': 'fun...                                   0.999401
# {'name': 'Lcals_HYDRO_2D', 'type': 'function'}                                            NaN
# {'name': 'Lcals_HYDRO_2D.default', 'type': 'fun...                                   0.448869
# {'name': 'Lcals_INT_PREDICT', 'type': 'function'}                                         NaN
# {'name': 'Lcals_INT_PREDICT.default', 'type': '...                                   1.003546
# {'name': 'Lcals_PLANCKIAN', 'type': 'function'}                                           NaN
# {'name': 'Lcals_PLANCKIAN.default', 'type': 'fu...                                   0.986089
# {'name': 'Lcals_TRIDIAG_ELIM', 'type': 'function'}                                        NaN
# {'name': 'Lcals_TRIDIAG_ELIM.default', 'type': ...                                   0.999516
# {'name': 'Polybench', 'type': 'function'}                                            0.054018
# {'name': 'Polybench_2MM', 'type': 'function'}                                             NaN
# {'name': 'Polybench_2MM.default', 'type': 'func...                                   0.110919
# {'name': 'Polybench_3MM', 'type': 'function'}                                        2.494418
# {'name': 'Polybench_3MM.default', 'type': 'func...                                   0.087775
# {'name': 'Polybench_ADI', 'type': 'function'}                                             NaN
# {'name': 'Polybench_ADI.default', 'type': 'func...                                   0.279524
# {'name': 'Polybench_ATAX', 'type': 'function'}                                            NaN
# {'name': 'Polybench_ATAX.default', 'type': 'fun...                                   0.136832
# {'name': 'Polybench_FDTD_2D', 'type': 'function'}                                         NaN
# {'name': 'Polybench_FDTD_2D.default', 'type': '...                                   0.194062
# {'name': 'Polybench_FLOYD_WARSHALL', 'type': 'f...                                        NaN
# {'name': 'Polybench_FLOYD_WARSHALL.default', 't...                                   0.178487
# {'name': 'Polybench_GEMM', 'type': 'function'}                                            NaN
# {'name': 'Polybench_GEMM.default', 'type': 'fun...                                   0.005747
# {'name': 'Polybench_GEMVER', 'type': 'function'}                                          NaN
# {'name': 'Polybench_GEMVER.default', 'type': 'f...                                   0.075188
# {'name': 'Polybench_GESUMMV', 'type': 'function'}                                         NaN
# {'name': 'Polybench_GESUMMV.default', 'type': '...                                   0.146726
# {'name': 'Polybench_HEAT_3D', 'type': 'function'}                                         NaN
# {'name': 'Polybench_HEAT_3D.default', 'type': '...                                   0.019293
# {'name': 'Polybench_JACOBI_1D', 'type': 'functi...                                        NaN
# {'name': 'Polybench_JACOBI_1D.default', 'type':...                                   0.998777
# {'name': 'Polybench_JACOBI_2D', 'type': 'functi...                                        NaN
# {'name': 'Polybench_JACOBI_2D.default', 'type':...                                   0.158944
# {'name': 'Polybench_MVT', 'type': 'function'}                                        2.500000
# {'name': 'Polybench_MVT.default', 'type': 'func...                                   0.129702
# {'name': 'Stream', 'type': 'function'}                                               0.049521
# {'name': 'Stream_ADD', 'type': 'function'}                                           2.481527
# {'name': 'Stream_ADD.default', 'type': 'function'}                                   0.999606
# {'name': 'Stream_COPY', 'type': 'function'}                                          2.500000
# {'name': 'Stream_COPY.default', 'type': 'functi...                                   0.999299
# {'name': 'Stream_DOT', 'type': 'function'}                                                NaN
# {'name': 'Stream_DOT.default', 'type': 'function'}                                   1.000615
# {'name': 'Stream_MUL', 'type': 'function'}                                                NaN
# {'name': 'Stream_MUL.default', 'type': 'function'}                                   0.998955
# {'name': 'Stream_TRIAD', 'type': 'function'}                                              NaN
# {'name': 'Stream_TRIAD.default', 'type': 'funct...                                   0.999598
#
#
#                                                    Machine clears_var
# node
# {'name': 'Base_Seq', 'type': 'function'}                 3.478914e-05
# {'name': 'Algorithm', 'type': 'function'}                4.632791e-04
# {'name': 'Algorithm_MEMCPY', 'type': 'function'}         2.036083e-01
# {'name': 'Algorithm_MEMCPY.default', 'type': 'f...       3.228626e-06
# {'name': 'Algorithm_MEMCPY.library', 'type': 'f...       5.026178e-04
# {'name': 'Algorithm_MEMSET', 'type': 'function'}         1.778705e-03
# {'name': 'Algorithm_MEMSET.default', 'type': 'f...       6.944848e-06
# {'name': 'Algorithm_MEMSET.library', 'type': 'f...       4.730707e-05
# {'name': 'Algorithm_REDUCE_SUM', 'type': 'funct...       2.100000e-01
# {'name': 'Algorithm_REDUCE_SUM.default', 'type'...       2.430705e-04
# {'name': 'Algorithm_SCAN', 'type': 'function'}           2.295091e-01
# {'name': 'Algorithm_SCAN.default', 'type': 'fun...       4.088701e-06
# {'name': 'Algorithm_SORT', 'type': 'function'}           2.388064e-01
# {'name': 'Algorithm_SORT.default', 'type': 'fun...       1.044090e-09
# {'name': 'Algorithm_SORTPAIRS', 'type': 'functi...       2.070596e-01
# {'name': 'Algorithm_SORTPAIRS.default', 'type':...       9.156100e-10
# {'name': 'Apps', 'type': 'function'}                     5.116651e-05
# {'name': 'Apps_CONVECTION3DPA', 'type': 'functi...       2.209159e-01
# {'name': 'Apps_CONVECTION3DPA.default', 'type':...       4.672752e-04
# {'name': 'Apps_DEL_DOT_VEC_2D', 'type': 'functi...       2.339580e-01
# {'name': 'Apps_DEL_DOT_VEC_2D.default', 'type':...       8.006068e-07
# {'name': 'Apps_DIFFUSION3DPA', 'type': 'function'}       2.040816e-01
# {'name': 'Apps_DIFFUSION3DPA.default', 'type': ...       7.056986e-05
# {'name': 'Apps_ENERGY', 'type': 'function'}              2.147849e-01
# {'name': 'Apps_ENERGY.default', 'type': 'functi...       2.711269e-08
# {'name': 'Apps_FIR', 'type': 'function'}                 2.426519e-01
# {'name': 'Apps_FIR.default', 'type': 'function'}         8.936327e-06
# {'name': 'Apps_HALOEXCHANGE', 'type': 'function'}        1.758460e-01
# {'name': 'Apps_HALOEXCHANGE.default', 'type': '...       7.306000e-04
# {'name': 'Apps_HALOEXCHANGE_FUSED', 'type': 'fu...       2.334574e-01
# {'name': 'Apps_HALOEXCHANGE_FUSED.default', 'ty...       9.115319e-04
# {'name': 'Apps_LTIMES', 'type': 'function'}              2.106243e-01
# {'name': 'Apps_LTIMES.default', 'type': 'functi...       1.179490e-09
# {'name': 'Apps_LTIMES_NOVIEW', 'type': 'function'}       2.040816e-01
# {'name': 'Apps_LTIMES_NOVIEW.default', 'type': ...       8.356900e-10
# {'name': 'Apps_MASS3DPA', 'type': 'function'}            2.035634e-01
# {'name': 'Apps_MASS3DPA.default', 'type': 'func...       3.361978e-03
# {'name': 'Apps_NODAL_ACCUMULATION_3D', 'type': ...       2.222222e-01
# {'name': 'Apps_NODAL_ACCUMULATION_3D.default', ...       5.185116e-07
# {'name': 'Apps_PRESSURE', 'type': 'function'}            1.386759e-01
# {'name': 'Apps_PRESSURE.default', 'type': 'func...       3.174149e-08
# {'name': 'Apps_VOL3D', 'type': 'function'}               2.427470e-01
# {'name': 'Apps_VOL3D.default', 'type': 'function'}       4.084956e-06
# {'name': 'Basic', 'type': 'function'}                    1.115161e-04
# {'name': 'Basic_DAXPY', 'type': 'function'}              1.600000e-01
# {'name': 'Basic_DAXPY.default', 'type': 'functi...       6.826100e-07
# {'name': 'Basic_DAXPY_ATOMIC', 'type': 'function'}       2.448980e-01
# {'name': 'Basic_DAXPY_ATOMIC.default', 'type': ...       3.452340e-07
# {'name': 'Basic_IF_QUAD', 'type': 'function'}            2.343750e-01
# {'name': 'Basic_IF_QUAD.default', 'type': 'func...       4.687810e-09
# {'name': 'Basic_INDEXLIST', 'type': 'function'}          1.975200e-01
# {'name': 'Basic_INDEXLIST.default', 'type': 'fu...       1.448760e-09
# {'name': 'Basic_INDEXLIST_3LOOP', 'type': 'func...       2.399179e-01
# {'name': 'Basic_INDEXLIST_3LOOP.default', 'type...       5.225440e-09
# {'name': 'Basic_INIT3', 'type': 'function'}              2.492953e-01
# {'name': 'Basic_INIT3.default', 'type': 'functi...       3.866309e-08
# {'name': 'Basic_INIT_VIEW1D', 'type': 'function'}        1.734294e-01
# {'name': 'Basic_INIT_VIEW1D.default', 'type': '...       1.077589e-08
# {'name': 'Basic_INIT_VIEW1D_OFFSET', 'type': 'f...       2.448980e-01
# {'name': 'Basic_INIT_VIEW1D_OFFSET.default', 't...       3.998320e-08
# {'name': 'Basic_MAT_MAT_SHARED', 'type': 'funct...       2.500000e-01
# {'name': 'Basic_MAT_MAT_SHARED.default', 'type'...       3.392480e-07
# {'name': 'Basic_MULADDSUB', 'type': 'function'}          2.471353e-01
# {'name': 'Basic_MULADDSUB.default', 'type': 'fu...       3.525944e-08
# {'name': 'Basic_NESTED_INIT', 'type': 'function'}        2.433474e-01
# {'name': 'Basic_NESTED_INIT.default', 'type': '...       1.471945e-06
# {'name': 'Basic_PI_ATOMIC', 'type': 'function'}          2.441266e-01
# {'name': 'Basic_PI_ATOMIC.default', 'type': 'fu...       8.633281e-03
# {'name': 'Basic_PI_REDUCE', 'type': 'function'}          2.396629e-01
# {'name': 'Basic_PI_REDUCE.default', 'type': 'fu...       8.289638e-03
# {'name': 'Basic_REDUCE3_INT', 'type': 'function'}        2.343750e-01
# {'name': 'Basic_REDUCE3_INT.default', 'type': '...       1.040289e-02
# {'name': 'Basic_REDUCE_STRUCT', 'type': 'functi...       1.728306e-01
# {'name': 'Basic_REDUCE_STRUCT.default', 'type':...       5.333827e-05
# {'name': 'Basic_TRAP_INT', 'type': 'function'}           9.778604e-02
# {'name': 'Basic_TRAP_INT.default', 'type': 'fun...       5.129413e-04
# {'name': 'Lcals', 'type': 'function'}                    4.449650e-04
# {'name': 'Lcals_DIFF_PREDICT', 'type': 'function'}       2.079084e-01
# {'name': 'Lcals_DIFF_PREDICT.default', 'type': ...       5.241000e-11
# {'name': 'Lcals_EOS', 'type': 'function'}                2.280610e-01
# {'name': 'Lcals_EOS.default', 'type': 'function'}        2.435354e-07
# {'name': 'Lcals_FIRST_DIFF', 'type': 'function'}         2.446051e-01
# {'name': 'Lcals_FIRST_DIFF.default', 'type': 'f...       2.266741e-07
# {'name': 'Lcals_FIRST_MIN', 'type': 'function'}          2.031417e-01
# {'name': 'Lcals_FIRST_MIN.default', 'type': 'fu...       1.075674e-04
# {'name': 'Lcals_FIRST_SUM', 'type': 'function'}          2.368521e-01
# {'name': 'Lcals_FIRST_SUM.default', 'type': 'fu...       3.222649e-08
# {'name': 'Lcals_GEN_LIN_RECUR', 'type': 'functi...       2.201828e-01
# {'name': 'Lcals_GEN_LIN_RECUR.default', 'type':...       2.165404e-08
# {'name': 'Lcals_HYDRO_1D', 'type': 'function'}           1.860543e-01
# {'name': 'Lcals_HYDRO_1D.default', 'type': 'fun...       1.403904e-08
# {'name': 'Lcals_HYDRO_2D', 'type': 'function'}           2.378324e-01
# {'name': 'Lcals_HYDRO_2D.default', 'type': 'fun...       6.311305e-04
# {'name': 'Lcals_INT_PREDICT', 'type': 'function'}        2.157140e-01
# {'name': 'Lcals_INT_PREDICT.default', 'type': '...       1.574843e-06
# {'name': 'Lcals_PLANCKIAN', 'type': 'function'}          1.219103e-01
# {'name': 'Lcals_PLANCKIAN.default', 'type': 'fu...       3.583305e-05
# {'name': 'Lcals_TRIDIAG_ELIM', 'type': 'function'}       2.448980e-01
# {'name': 'Lcals_TRIDIAG_ELIM.default', 'type': ...       1.600044e-08
# {'name': 'Polybench', 'type': 'function'}                7.067193e-05
# {'name': 'Polybench_2MM', 'type': 'function'}            2.448980e-01
# {'name': 'Polybench_2MM.default', 'type': 'func...       1.431790e-04
# {'name': 'Polybench_3MM', 'type': 'function'}            2.357099e-01
# {'name': 'Polybench_3MM.default', 'type': 'func...       9.510570e-05
# {'name': 'Polybench_ADI', 'type': 'function'}            1.875000e-01
# {'name': 'Polybench_ADI.default', 'type': 'func...       1.383069e-04
# {'name': 'Polybench_ATAX', 'type': 'function'}           2.453341e-01
# {'name': 'Polybench_ATAX.default', 'type': 'fun...       2.696680e-04
# {'name': 'Polybench_FDTD_2D', 'type': 'function'}        2.343750e-01
# {'name': 'Polybench_FDTD_2D.default', 'type': '...       3.342556e-04
# {'name': 'Polybench_FLOYD_WARSHALL', 'type': 'f...       2.448980e-01
# {'name': 'Polybench_FLOYD_WARSHALL.default', 't...       6.237115e-06
# {'name': 'Polybench_GEMM', 'type': 'function'}           2.318128e-01
# {'name': 'Polybench_GEMM.default', 'type': 'fun...       4.576711e-07
# {'name': 'Polybench_GEMVER', 'type': 'function'}         1.976258e-01
# {'name': 'Polybench_GEMVER.default', 'type': 'f...       1.014984e-03
# {'name': 'Polybench_GESUMMV', 'type': 'function'}        0.000000e+00
# {'name': 'Polybench_GESUMMV.default', 'type': '...       4.341432e-04
# {'name': 'Polybench_HEAT_3D', 'type': 'function'}        2.332841e-01
# {'name': 'Polybench_HEAT_3D.default', 'type': '...       4.861931e-06
# {'name': 'Polybench_JACOBI_1D', 'type': 'functi...       2.335557e-01
# {'name': 'Polybench_JACOBI_1D.default', 'type':...       1.132521e-08
# {'name': 'Polybench_JACOBI_2D', 'type': 'functi...       2.444511e-01
# {'name': 'Polybench_JACOBI_2D.default', 'type':...       2.479680e-05
# {'name': 'Polybench_MVT', 'type': 'function'}            2.341902e-01
# {'name': 'Polybench_MVT.default', 'type': 'func...       2.324194e-04
# {'name': 'Stream', 'type': 'function'}                   2.084165e-04
# {'name': 'Stream_ADD', 'type': 'function'}               2.415457e-01
# {'name': 'Stream_ADD.default', 'type': 'function'}       8.814320e-08
# {'name': 'Stream_COPY', 'type': 'function'}              2.305196e-01
# {'name': 'Stream_COPY.default', 'type': 'functi...       3.755765e-08
# {'name': 'Stream_DOT', 'type': 'function'}               1.580293e-01
# {'name': 'Stream_DOT.default', 'type': 'function'}       5.402258e-07
# {'name': 'Stream_MUL', 'type': 'function'}               2.393389e-01
# {'name': 'Stream_MUL.default', 'type': 'function'}       6.833360e-09
# {'name': 'Stream_TRIAD', 'type': 'function'}             2.242087e-04
# {'name': 'Stream_TRIAD.default', 'type': 'funct...       3.449161e-08

# %% [markdown]
# ## 6. Visualization Thicket Functions

# %% [markdown]
# ### 6.1 Displaying Heatmap
#
# The `display_heatmap` function will display a color encoded map with the color representing the magnitude of the value for that specific node and column cell. <br>
#
# Columns must be from the aggregated statistics table.

# %% [markdown]
# #### Single Index Thicket Example

# %%
metrics = ["time (exc)_std","time (exc)_var"]
th.display_heatmap(clang_th, columns=metrics)
# Out:
# <AxesSubplot: ylabel='node'>

# %% [markdown]
# #### Multi-Indexed Thicket Example
# Example will show how to pass a columnar joined thicket object. When passing a columnar joined thicket object, the columns argument will now take a list of tuples. Each tuple will consist of two elements. The first element will always be the column index, and the second element will be an associated column under the column index you passed.<br>
#
#  - Example: (column_index, column_name) -> ("GCC", "Machine clears")

# %%
metrics = [("Clang","time (exc)_std"),("Clang","time (exc)_var")]

# %%
th.display_heatmap(combined_th,columns=metrics)
# Out:
# Text(0.5, 1.0, 'Clang')

# %% [markdown]
# #### Example of Not Passing the Same Column Index for Multi-Indexed Thicket

# %%
metrics = [("Clang","time (exc)_std"),("GCC","Machine clears_var")]

# %%
th.display_heatmap(combined_th,columns=metrics)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 th.display_heatmap(combined_th,columns=metrics)
#
# File ~/opt/anaconda3/envs/llnl-dev/lib/python3.8/site-packages/thicket/stats/display_heatmap.py:47, in display_heatmap(thicket, columns, **kwargs)
#      45 for i in range(1, len(columns)):
#      46     if initial_idx != columns[i][0]:
# ---> 47         raise ValueError(
#      48             "Columns specified as tuples must have the same column index (first element)."
#      49         )
#      50     else:
#      51         cols.append(columns[i][1])
#
# ValueError: Columns specified as tuples must have the same column index (first element).

# %% [markdown]
# ### 6.2 Displaying Histogram
#
# The `display_histogram` function will display a histogram for a user passed node and columns. Node and column must come from the performance data table. <br>
#
# A histogram allows for a user to see outliers and the overall distribution of their data.

# %%
# Getting nodes to pass
n = pd.unique(combined_th.dataframe.reset_index()["node"])[4]

# %% [markdown]
# #### Single Index Thicket Example

# %%
th.display_histogram(clang_th,node=n,column="Machine clears")

# %% [markdown]
# #### Multi-Indexed Thicket Example
#
# Example will show how to pass a columnar joined thicket object. When passing a columnar joined thicket object, the columns argument will now take a list of tuples. Each tuple will consist of two elements. The first element will always be the column index, and the second element will be an associated column under the column index you passed.<br>
#
#  - Example: (column_index, column_name) -> ("GCC", "Machine clears")

# %%
th.display_histogram(combined_th,node=n,column=("Clang","Machine clears"))

# %% [markdown]
# #### Example of Error if Not Passing a Hatchet Node

# %%
n = 'not_hatchet_node'

# %%
th.display_histogram(combined_th,node=n,column=("Clang","Machine clears"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 th.display_histogram(combined_th,node=n,column=("Clang","Machine clears"))
#
# File ~/opt/anaconda3/envs/llnl-dev/lib/python3.8/site-packages/thicket/stats/display_histogram.py:33, in display_histogram(thicket, node, column, **kwargs)
#      28     raise ValueError(
#      29         "To see a list of valid columns, run Thicket.get_perf_columns()."
#      30     )
#      32 if not isinstance(node, ht.node.Node):
# ---> 33     raise ValueError(
#      34         "Value passed to node argument must be of type hatchet.node.Node."
#      35     )
#      37 verify_thicket_structures(
#      38     thicket.dataframe, index=["node", "profile"], columns=[column]
#      39 )
#      41 # thicket object without columnar index
#
# ValueError: Value passed to node argument must be of type hatchet.node.Node.

# %% [markdown]
# ### 6.3 Displaying Boxplot
#
# The `display_boxplot` function will display a boxplot for each passed in node(s) and column(s). The passed nodes and columns must be from the performance data table.

# %%
# Getting nodes to pass
n = pd.unique(combined_th.dataframe.reset_index()["node"])[0:2].tolist()

# %% [markdown]
# #### Single Index Thicket Example

# %%
th.display_boxplot(clang_th,nodes=n,columns=["Machine clears","Frontend latency"])
# Out:
# <AxesSubplot: xlabel='node', ylabel=' '>

# %% [markdown]
# #### Multi-Indexed Thicket Example
# Example will show how to pass a columnar joined thicket object. When passing a columnar joined thicket object, the columns argument will now take a list of tuples. Each tuple will consist of two elements. The first element will always be the column index, and the second element will be an associated column under the column index you passed.<br>
#
#  - Example: (column_index, column_name) -> ("GCC", "Machine clears")

# %%
th.display_boxplot(combined_th,nodes=n,columns=[("Clang","time (exc)"),("Clang","Machine clears")])
# Out:
# <AxesSubplot: xlabel='node', ylabel=' '>

# %% [markdown]
# #### Example of Error if Not Passing Same Column Index

# %%
th.display_boxplot(combined_th,nodes=n,columns=[("Clang","time (exc)"),("GCC","Machine clears")])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 th.display_boxplot(combined_th,nodes=n,columns=[("Clang","time (exc)"),("GCC","Machine clears")])
#
# File ~/opt/anaconda3/envs/llnl-dev/lib/python3.8/site-packages/thicket/stats/display_boxplot.py:74, in display_boxplot(thicket, nodes, columns, **kwargs)
#      72 for i in range(1, len(columns)):
#      73     if initial_idx != columns[i][0]:
# ---> 74         raise ValueError(
#      75             "Columns specified as tuples must have the same column index (first element)"
#      76         )
#      77     else:
#      78         cols.append(columns[i][1])
#
# ValueError: Columns specified as tuples must have the same column index (first element)
